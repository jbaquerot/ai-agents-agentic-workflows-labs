# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Create a Structured Meal & Grocery Planner with CrewAI

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# You are an individual who loves cooking delicious meals but struggles with the overwhelming decisions around meal planning, budgeting, and grocery shopping. In the past, this involved hours of manual work – browsing endless recipes, calculating ingredient quantities, checking prices, organizing shopping lists, and hoping everything fits your budget and dietary needs. By leveraging AI agents through CrewAI, you can dramatically accelerate this process while ensuring you get exactly what you need for a perfect meal.
#
# In this project, you'll implement an end-to-end meal planning and grocery shopping system using AI agents. You'll create:
#
# - **Structured data models** using Pydantic to ensure consistent grocery lists and meal plans.
# - **Specialized AI agents** for recipe research, shopping organization, and budget optimization.
# - **A coordinated workflow** that transforms a simple meal craving into a complete, budget-conscious shopping strategy.
# - **A reusable YAML configuration** that allows you to define agents, tasks, and crew behavior declaratively, making the system easier to maintain and scale.
# - **A class-based CrewBase setup** that combines structured Python code with external YAML files, enabling hooks for pre-processing inputs and post-processing outputs, and automating the agent-task pipeline.
#
# By the end of this project, you'll have a reusable framework that can generate comprehensive, organized shopping plans for any meal within minutes rather than hours — all with just a few lines of configuration and code.

# %% [markdown]
# ## __Table of Contents__
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Creating-the-Grocery-Shopping-Assistant-Structure">Creating the Grocery Shopping Assistant Structure</a>
#         <ol>
#             <li><a href="#GroceryItem">GroceryItem</a></li>
#             <li><a href="#MealPlan">MealPlan</a></li>
#             <li><a href="#ShoppingCategory">ShoppingCategory</a></li>
#             <li><a href="#GroceryShoppingPlan">GroceryShoppingPlan</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Setting-Up-Our-LLM-and-Essential-Tools">Setting Up Our LLM and Essential Tools</a>
#         <ol>
#             <li><a href="#Setting-Up-SerperDevTool">Setting Up SerperDevTool</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Creating-Our-AI-Agent-Workflow-with-CrewAI">Creating Our AI Agent Workflow with CrewAI</a>
#         <ol>
#             <li><a href="#Defining-Our-Meal-Planning-Agent">Defining Our Meal Planning Agent</a></li>
#             <li><a href="#Defining-Our-Meal-Planning-Task">Defining Our Meal Planning Task</a></li>
#             <li><a href="#Creating-and-Running-Our-Meal-Planning-Crew">Creating and Running Our Meal Planning Crew</a></li>
#             <li><a href="#Creating-Our-Shopping-Organization-Agent">Creating Our Shopping Organization Agent</a></li>
#             <li><a href="#Defining-the-Shopping-Organization-Task">Defining the Shopping Organization Task</a></li>
#             <li><a href="#Building-Our-Two-Agent-Grocery-Crew">Building Our Two-Agent Grocery Crew</a></li>
#             <li><a href="#Adding-Financial-Intelligence-with-Budget-Advisor-Agent">Adding Financial Intelligence with Budget Advisor Agent</a></li>
#             <li><a href="#Defining-the-Budget-Analysis-Task">Defining the Budget Analysis Task</a></li>
#             <li><a href="#Using-YAML-with-CrewAI---Food-Leftover-Agent-and-Task">Using YAML with CrewAI - Food Leftover Agent and Task</a></li>
#             <li><a href="#Using-CrewBase-and-Decorators-with-CrewAI">Using CrewBase and Decorators with CrewAI</a></li>
#             <li><a href="#Defining-Our-Summary-Agent-and-Task">Defining Our Summary Agent and Task</a></li>
#             <li><a href="#Assembling-Our-Complete-Grocery-Planning-Team">Assembling Our Complete Grocery Planning Team</a></li>
#             <li><a href="#Executing-Our-Complete-Grocery-Planning-Workflow">Executing Our Complete Grocery Planning Workflow</a></li>
#             <li><a href="#Understanding-Your-Complete-Grocery-Shopping-Guide">Understanding Your Complete Grocery Shopping Guide</a></li>
#         </ol>
#      </li>
#     <li><a href="#Exercises">Exercises</a></li>
#     <li><a href="#Authors">Authors</a></li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab, you will be able to:
#
# - **Structure grocery planning data** using `Pydantic` models and structured outputs to ensure consistent formats across all agent responses.
# - **Define intelligent food planning agents** using both Python-based `@CrewBase` classes and YAML configuration files for modularity and reuse.
# - **Create crew objects** that assign agents to tasks, enabling coordinated multi-agent workflows for meal planning and grocery management.
# - **Implement a multi-stage planning workflow** with CrewAI that processes user inputs through research, shopping list generation, budgeting, and leftover management.
# - **Organize ingredient data by store sections** to produce structured shopping lists with estimated prices and category-wise grouping.
# - **Compile a complete grocery shopping guide** that combines outputs from all agents into a cohesive report with recipes, cost breakdowns, and money-saving tips.

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pydantic`](https://docs.pydantic.dev/latest/) for data validation and creating structured grocery item, meal plan, and shopping list models
# *   [`langchain`](https://python.langchain.com/docs/get_started/introduction) for language model orchestration and integration with recipe research agents
# *   [`crewai`](https://www.crewai.io/) for creating coordinated AI agent workflows that handle meal planning, shopping organization, and budget analysis
# *   [`crewai-tools`](https://github.com/joaomdmoura/crewAI-tools) for specialized tools such as SerperDevTool to enable web-based recipe research and price checking
# *   [`IPython.display`](https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html) for rich formatting and display of structured grocery data and shopping plans
# *   [`os`](https://docs.python.org/3/library/os.html) for managing API keys and environment variables needed for web search functionality
# *   [`warnings`](https://docs.python.org/3/library/warnings.html) for suppressing deprecation and user warnings to maintain clean output during meal planning operations

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# %pip install langchain==0.3.20 | tail -n 1
# %pip install crewai==0.141.0 | tail -n 1
# %pip install langchain-community==0.3.19 | tail -n 1
# %pip install langchain-openai==0.3.25 | tail -n 1
# %pip install duckduckgo-search==7.5.2 | tail -n 1
# %pip install crewai-tools==0.51.1 | tail -n 1
# %pip install databricks-sdk==0.46.0 | tail -n 1
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.41->langchain==0.3.20) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Successfully installed crewai-0.141.0 litellm-1.72.6
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.19) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedchain 0.1.128 requires langchain-openai<0.3.0,>=0.2.1, but you have langchain-openai 0.3.25 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Successfully installed langchain-openai-0.3.25
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Successfully installed duckduckgo-search-7.5.2 primp-1.0.0
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Successfully installed crewai-tools-0.51.1 langchain-openai-0.2.14
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Successfully installed databricks-sdk-0.46.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install litellm
import litellm
litellm.ssl_verify = False
# Out:
# Requirement already satisfied: litellm in ./.venv/lib/python3.12/site-packages (1.72.6)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from litellm) (3.13.3)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from litellm) (8.3.1)
# Requirement already satisfied: httpx>=0.23.0 in ./.venv/lib/python3.12/site-packages (from litellm) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in ./.venv/lib/python3.12/site-packages (from litellm) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in ./.venv/lib/python3.12/site-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in ./.venv/lib/python3.12/site-packages (from litellm) (4.26.0)
# Requirement already satisfied: openai>=1.68.2 in ./.venv/lib/python3.12/site-packages (from litellm) (1.109.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from litellm) (2.12.5)
# Requirement already satisfied: python-dotenv>=0.2.0 in ./.venv/lib/python3.12/site-packages (from litellm) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in ./.venv/lib/python3.12/site-packages (from litellm) (0.12.0)
# Requirement already satisfied: tokenizers in ./.venv/lib/python3.12/site-packages (from litellm) (0.20.3)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.30.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.68.2->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.68.2->litellm) (0.10.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai>=1.68.2->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.12/site-packages (from openai>=1.68.2->litellm) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./.venv/lib/python3.12/site-packages (from openai>=1.68.2->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->litellm) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->litellm) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.12/site-packages (from tiktoken>=0.7.0->litellm) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from tiktoken>=0.7.0->litellm) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm) (1.22.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.venv/lib/python3.12/site-packages (from tokenizers->litellm) (0.36.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm) (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (2.6.3)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We are going to download a python file which contains the `CrewBase` class. The reason why we are downloading it here, will be discussed later.

# %%
import urllib.request

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/3xGOgzMOv5jhRsA3A8N9fQ/leftover.py"
urllib.request.urlretrieve(url, "leftover.py")
print("leftover.py downloaded successfully")
# Out:
# leftover.py downloaded successfully

# %% [markdown]
# ### Importing Required Libraries
# Since we are creating our own module, Jupyter notebooks might not automatically recognize it — especially in custom or multi-file setups. To ensure our module is importable, we’ll add the current directory to Python’s module search path using sys.path.append('.').

# %%
import sys
sys.path.append(".")

# %% [markdown]
# We'll use ```LeftoversCrew``` later in the lab, but let's double-check it's availability now. If you get an import error, first check that ```leftover.py``` is in your current directory. If it is, try restarting the Jupyter kernel. If the problem persists, double-check that you've written the correct import statement.

# %%
from leftover import LeftoversCrew

# %% [markdown]
# Files in  current directory:

# %%
import os

files = os.listdir('.')
print(files)
# Out:
# ['02_LLM-Powered Data Science-v1.ipynb', '10_design-patterns-v1.ipynb', '11_CrewAI-101-v1.ipynb', '04_Tool-Calling-v1.ipynb', '.claude', 'leftover.py', '__pycache__', 'README.md', '09_ReAct-v1.ipynb', '05_chat-with-your-dataframe-using-langchain-v1.ipynb', '.gitignore', '.env', '.venv', '03_Interactive Tool-Calling Agent-v1.ipynb', '12_Create a Structured Meal Grocery Planner with CrewAI.ipynb', '.git', '.vscode', '06_LangGraph101-v1.ipynb', '08_Reflexion Agent-v1.ipynb', '07_Tweet-Reflection-Agent-v1.ipynb', 'data', '01_Hello World-v1.ipynb']

# %%
from pydantic import BaseModel, Field
from typing import List, Dict, Optional
from IPython.display import display, JSON, Markdown
from datetime import datetime
import os

# %% [markdown]
# ## Creating the Grocery Shopping Assistant Structure
#
# To create our grocery shopping assistant, we are going to begin by creating the blueprints (a.k.a. classes) to manage the structure. Why? Because when you're dealing with grocery lists, meal plans, and shopping data, you need everything organized in a predictable format. Without structure, you might get a shopping list that says "some chicken" instead of "2 lbs chicken breast" - not very helpful when you're at the store!
#
# To do that, we are going to use **Pydantic**, which acts like a strict organizer for our data. Think of it as creating templates that ensure every grocery item has exactly what we need: a name, quantity, price, and store section.
#
# #### Why Are We Creating These Classes?
#
# We are creating these classes to **organize and structure grocery shopping data** in a clear and practical way. Instead of handling messy, unstructured text such as "get some chicken and vegetables," we break down shopping into smaller, structured parts that our AI agents can work with reliably.
#
# Pydantic's `BaseModel` helps structure and validate our grocery data easily. For example, if we define a `GroceryItem` model with `name: str` and `estimated_price: str`, it ensures that every grocery item must have both a name and a price estimate. `Field` adds extra rules and descriptions, like explaining that `quantity` should be formatted as "2 lbs" or "1 gallon". `List` from `typing` allows complex data structures, like a `ShoppingCategory` model storing `items: List[GroceryItem]` - a produce section containing multiple vegetables.
#
# This makes handling grocery data simple and reliable, ensuring that when our AI agent says "buy chicken," it specifically means "buy 2 lbs of chicken breast for $8-12 from the meat section." ([Pydantic Docs](https://docs.pydantic.dev/latest/concepts/models/))

# %% [markdown]
# ### Our Grocery Shopping Data Structure
#
# 1. ```GroceryItem```         → Individual grocery item with details
# 2. ```MealPlan```           → Recipe information with researched ingredients
# 3. ```ShoppingCategory```   → Store section with organized items
# 4. ```GroceryShoppingPlan``` → Complete shopping strategy with budget analysis

# %% [markdown]
# ### **`GroceryItem`**
#
# Think of this as designing the shopping list template before going to the store. BaseModel gives us the foundation, Field decorates our items with clear descriptions. This structure helps both humans and AI understand grocery data consistently, and includes several key string inputs:
#
# - **`name`** – The specific grocery item to purchase (for example, "Chicken Breast").
# - **`quantity`** – How much to buy in clear measurements (for example, "2 lbs", "1 gallon").
# - **`estimated_price`** – The expected cost range for budgeting (for example, "$8-12").
# - **`category`** – Which store section to find it in (for example, "Meat", "Produce", "Dairy").

# %%
class GroceryItem(BaseModel):
    """Individual grocery item"""
    name: str = Field(description="Name of the grocery item")
    quantity: str = Field(description="Quantity needed (for example, '2 lbs', '1 gallon')")
    estimated_price: str = Field(description="Estimated price (for example, '$3-5')")
    category: str = Field(description="Store section (for example, 'Produce', 'Dairy')")

# %% [markdown]
# We create an instance of a `GroceryItem`, which holds **one specific grocery item** along with its purchase details and store location.
#
# This **standard format** helps our AI shopping organizer stay organized and maintain consistency when creating shopping lists.

# %%
sample_item = GroceryItem(
    name="Chicken Breast",
    quantity="2 lbs",
    estimated_price="$8-12",
    category="Meat"
)

# %% [markdown]
# The result is essentially a **JSON object** or a **Python dictionary**.
#
# Without formatting, our `sample_item` displays as:

# %%
sample_item
# Out:
# GroceryItem(name='Chicken Breast', quantity='2 lbs', estimated_price='$8-12', category='Meat')

# %%
type(sample_item)
# Out:
# __main__.GroceryItem

# %% [markdown]
# We can use the `display` function to **view the output in a much cleaner format**, especially noting its **organized, readable structure**. Since this is a single grocery item, all fields become clearly visible—**each property shows exactly what information our AI agents will work with**.

# %%
# Display structured data
print("🛒 Sample Grocery Item Structure:")
display(JSON(sample_item.model_dump()))
# Out:
# 🛒 Sample Grocery Item Structure:

# %% [markdown]
# This class lets us **create multiple grocery items**. Here, we're generating a **sample grocery item for chicken breast** so we can demonstrate how individual items are structured.
#
# You can create multiple grocery items to build complete shopping lists:
# - The first might cover proteins - essential ingredients for main dishes
# - The second could focus on vegetables that provide nutrition and flavor
# - A third might include pantry staples such as rice or cooking oils

# %% [markdown]
# ### **`MealPlan`**
#
# It represents a complete meal with all the details needed for cooking, including:
#
# - **`meal_name`** – The name of the dish being prepared (for example, "Chicken Stir Fry").
# - **`difficulty_level`** – How challenging it is to cook ("Easy", "Medium", "Hard").
# - **`servings`** – Number of people the meal will feed (integer value).
# - **`researched_ingredients`** – List of ingredients found through AI research (note this is a list).

# %%
class MealPlan(BaseModel):
    """Simple meal plan"""
    meal_name: str = Field(description="Name of the meal")
    difficulty_level: str = Field(description="'Easy', 'Medium', 'Hard'")
    servings: int = Field(description="Number of people it serves")
    researched_ingredients: List[str] = Field(description="Ingredients found through research")

# %% [markdown]
# Similarly, we can create an instance of a `MealPlan`, which holds **one complete meal** along with its cooking difficulty and researched ingredient list.

# %%
sample_meal = MealPlan(
    meal_name="Chicken Stir Fry",
    difficulty_level="Easy",
    servings=4,
    researched_ingredients=["chicken breast", "broccoli", "bell peppers", "garlic", "soy sauce", "rice"]
)

# %%
sample_meal
# Out:
# MealPlan(meal_name='Chicken Stir Fry', difficulty_level='Easy', servings=4, researched_ingredients=['chicken breast', 'broccoli', 'bell peppers', 'garlic', 'soy sauce', 'rice'])

# %%
print("\n🍽️ Sample Meal Plan Structure:")
display(JSON(sample_meal.model_dump()))
# Out:
# 🍽️ Sample Meal Plan Structure:

# %% [markdown]
# ### **`ShoppingCategory`**
#
# It organizes items by store layout for efficient shopping, containing:
#
# - **`section_name`** – The store department name (for example, "Produce", "Meat & Poultry").
# - **`items`** – A collection of GroceryItem objects in this section (note this is a list).
# - **`estimated_total`** – The expected cost for all items in this category.

# %%
class ShoppingCategory(BaseModel):
    """Store section with items"""
    section_name: str = Field(description="Store section (for example, 'Produce', 'Dairy')")
    items: List[GroceryItem] = Field(description="Items in this section")
    estimated_total: str = Field(description="Estimated cost for this section")

# %% [markdown]
# Below, we create an instance of a `ShoppingCategory`, which holds **one store section** along with multiple grocery items and a cost estimate.
# Notice how `items: List[GroceryItem]` allows us to **group multiple grocery items together** - this is where our individual `GroceryItem` objects get organized by store layout. Instead of a single item, we can include an entire list of items that belong in the same store section, making shopping more efficient.

# %%
sample_section = ShoppingCategory(
    section_name="Produce",
    items=[
        GroceryItem(name="Bell Peppers", quantity="3 pieces", estimated_price="$3-4", category="Produce"),
        GroceryItem(name="Onions", quantity="2 lbs", estimated_price="$2-3", category="Produce")
    ],
    estimated_total="$5-7"
)

# %%
print("\n🏪 Sample Shopping Section:")
display(JSON(sample_section.model_dump()))
# Out:
# 🏪 Sample Shopping Section:

# %% [markdown]
# ### **`GroceryShoppingPlan`**
#
# It is the master plan that combines everything into a complete shopping strategy:
#
# - **`total_budget`** – The overall spending limit for the shopping trip.
# - **`meal_plans`** – Collection of meals being prepared (note this is a list).
# - **`shopping_sections`** – Organized categories for store navigation (note this is a list).
# - **`shopping_tips`** – Money-saving advice and practical suggestions (note this is a list).

# %%
class GroceryShoppingPlan(BaseModel):
    """Complete simplified shopping plan"""
    total_budget: str = Field(description="Total planned budget")
    meal_plans: List[MealPlan] = Field(description="Planned meals")
    shopping_sections: List[ShoppingCategory] = Field(description="Organized by store sections")
    shopping_tips: List[str] = Field(description="Money-saving and efficiency tips")

# %% [markdown]
# We can create a `GroceryShoppingPlan` object—this represents the **complete shopping strategy**, compiled from the meal plans and shopping sections we've created. Below is the just an example of how it looks and **not an executable code**.

# %% [raw]
# weekly_shopping_plan = GroceryShoppingPlan(
#     total_budget="$40-50",
#     meal_plans=[breakfast_meal, lunch_meal, dinner_meal],  # List of MealPlan objects
#     shopping_sections=[dairy_section, meat_section, pantry_section, produce_section],  # List of ShoppingCategory objects
#     shopping_tips=[...]
# )

# %% [markdown]
# ## Setting Up Our LLM and Essential Tools
#
# We set up our **LLM (Large Language Model)**—this can be **any model** based on our needs. Here, we are going to use **Mistral AI Ministral 8B**.

# %%
# %%capture
import os
from crewai_tools import SerperDevTool
from crewai import Agent, Task, Crew, Process
from crewai import LLM

# Initialize LLM using Mistral AI
llm = LLM(
    model="mistral/ministral-8b-2512",
    api_key=os.environ.get("MISTRAL_API_KEY"),
)

# %% [markdown]
# ### Setting Up SerperDevTool
#
# **What is Serper?**
# Serper is a Google Search API that provides real-time web search capabilities to AI applications. It acts as a bridge between our AI agents and the vast information available on the internet.
#
# **Why are we using Serper in our workflow?**
# Our meal planning agents need access to current recipe information, ingredient prices, cooking techniques, and dietary alternatives. Without web access, our AI would be limited to outdated training data and couldn't find the latest recipes or seasonal ingredient information that makes meal planning practical and relevant.
#
# **How will we use Serper?**
# Our `meal_planner` agent will use Serper to:
# - Search for recipes that match specific dietary restrictions (for example, "gluten-free chicken stir fry").
# - Find cooking techniques appropriate for different skill levels (for example, "beginner-friendly stir fry methods").
# - Research ingredient substitutions and alternatives.
# - Check for seasonal availability and pricing information.
#
# To use `SerperDevTool`, we first need an **API key**—a crucial credential that grants access to web searches. Once we have the API key, we can import the library and integrate it into our meal planning workflow.
#
# > You will need to get the API Key from `serper.dev` website. To get the API key, create an account using your email if you have registered or login if you already have an account. Once you are logged in, you will be on the `Dashboard` section. Click on `API Keys` and you will find your API key. Copy the key and replace it with `API_KEY` here.
#
# To get the API key and for more details on `SerperDevTool` and its capabilities, visit the official webpage: [SerperDevTool Documentation](https://serper.dev/).

# %%
# Set up search tool (you'll need to add your API key)
os.environ['SERPER_API_KEY'] = os.getenv('SERPER_API_KEY')  # Replace with actual key

# %% [markdown]
# #### Meal and Grocery Planning Workflow Overview
#
# ![image (3).png](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/0crjoLc3Yn0JefQoJVUarA/image%20-3-.png)

# %% [markdown]
# ## Creating Our AI Agent Workflow with CrewAI
#
# We are going to use **CrewAI** to create our intelligent meal planning workflow. CrewAI allows us to build teams of specialized AI agents that work together seamlessly. We'll start by creating our first agent.
#
# ### Defining Our Meal Planning Agent
# We are creating our first **AI meal planning specialist**, responsible for researching recipes and creating detailed meal plans.
# - **Role and Goal** – The agent is assigned a clear identity as a "Meal Planner & Recipe Researcher" with the specific purpose of finding optimal recipes, ensuring focused culinary research.
# - **Backstory** – This provides context for how the agent approaches meal planning tasks, much like defining expertise in a professional chef or nutritionist who considers dietary needs and skill levels.
# - **Tools** – The agent is equipped with web search capabilities through `SerperDevTool()`, enabling access to real-time recipe information, cooking tips, and ingredient data.
# - **Verbose Mode (`verbose=False`)** – Stops detailed logs of the agent's thought process, keeping output clean and focused.

# %%
meal_planner = Agent(
    role="Meal Planner & Recipe Researcher",
    goal="Search for optimal recipes and create detailed meal plans",
    backstory="A skilled meal planner who researches the best recipes online, considering dietary needs, cooking skill levels, and budget constraints.",
    tools=[SerperDevTool()],
    llm=llm,
    verbose=False
)

# %% [markdown]
# ### Defining Our Meal Planning Task
#
# **What is a Task in CrewAI?**
# A Task in CrewAI is a specific assignment given to an AI agent. It defines what the agent should do, what inputs it will receive, and what output is expected. Tasks are the building blocks that turn AI agents into productive team members with clear responsibilities.
#
# We are assigning a structured meal planning task to our AI agent, ensuring clear expectations and a standardized output format. The `{meal_name}`, `{servings}`, `{budget}`, `{dietary_restrictions}`, and `{cooking_skill}` placeholders make the task dynamic and reusable, allowing it to adapt to different meal requests and personal preferences. Additionally, the results are getting saved in "meals.json" which is optional.

# %%
meal_planning_task = Task(
    description=(
        "Search for the best '{meal_name}' recipe for {servings} people within a {budget} budget. "
        "Consider dietary restrictions: {dietary_restrictions} and cooking skill level: {cooking_skill}. "
        "Find recipes that match the skill level and provide complete ingredient lists with quantities."
    ),
    expected_output="A detailed meal plan with researched ingredients, quantities, and cooking instructions appropriate for the skill level.",
    agent=meal_planner,
    output_pydantic=MealPlan,
    output_file="meals.json"
)

# %% [markdown]
# ### Creating and Running Our Meal Planning Crew
#
# **What is a Crew in CrewAI?**
# A Crew is like assembling a team of specialists to work on a project. Just as you might have a chef, a shopping assistant, and a budget manager working together to plan a meal, a CrewAI Crew coordinates multiple AI agents, each with their own tasks, to accomplish a complex workflow. The Crew manages how agents collaborate, share information, and execute their tasks in the right order.
#
# We initialize a CrewAI workflow with a single meal planning agent, executing the recipe research task in a sequential process, where the AI gathers structured meal insights for the specified recipe and requirements before storing the results. However, this is only a partial output, as we will later integrate all the Pydantic `BaseModel` objects defined earlier to structure the complete shopping plan.

# %%
from crewai import Crew, Process

meal_planner_crew = Crew(
    agents=[meal_planner],
    tasks=[meal_planning_task],
    process=Process.sequential,  # Ensures tasks are executed in order
    verbose=True
)

meal_planner_result = meal_planner_crew.kickoff(
    inputs={
        "meal_name": "Chicken Stir Fry",
        "servings": 4,
        "budget": "$25",                           
        "dietary_restrictions": ["no nuts"],       
        "cooking_skill": "beginner"                
    }
)
print("✅ Single meal planning completed!")
print("📋 Single Meal Results:")
print(meal_planner_result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: eac447f2-391b-4435-8ca7-4dd9fce2deb2                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Task: Search for the best 'Chicken Stir Fry' recipe for 4 people within a $25 budget. Consider dietary         │
# │  restrictions: ['no nuts'] and cooking skill level: beginner. Find recipes that match the skill level and       │
# │  provide complete ingredient lists with quantities.                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best beginner-friendly Chicken Stir Fry recipe for 4 people under $25, no nuts, with co  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best beginner-friendly Chicken Stir Fry recipe for 4 people under $25, no nuts,    │
# │  with complete ingredient lists and step-by-step instructions', 'type': 'search', 'num': 10, 'engine':          │
# │  'google'}, 'organic': [{'title': 'Easy Chicken Stir Fry - The Real Food Dietitians', 'link':                   │
# │  'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': 'Find the ingredient list with exact         │
# │  measurements in the recipe card below. ... Dietary. Dairy-FreeEgg-FreeGluten-freeGrain-FreeHigh ProteinNut-    │
# │  ...', 'position': 1}, {'title': 'Easy Chicken Stir Fry | 20 Minute Meal - Olive Real Food', 'link':            │
# │  'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/', 'snippet': '... Nut-Free Granola ·          │
# │  Homemade Granola Recipe Guide · Perfect Blueberry ... Alright, so there is a little strategy to consider when  │
# │  making this Easy ...', 'position': 2}, {'title': 'Delicious Chicken Cashew Stir Fry Recipe | TikTok', 'link':  │
# │  'https://www.tiktok.com/@christianpetracca_5/video/7229259699810585858?lang=en', 'snippet': 'Creamy Cashew     │
# │  Cheesecake (No-Bake) Ingredients: For the Crust: • 1 cup nuts (almonds, walnuts) • ½ cup dates • A pinch of    │
# │  salt For the Filling: ...', 'position': 3}, {'title': 'Sheet Pan Chicken Meatballs and More Recipes We Made    │
# │  This Week', 'link':                                                                                            │
# │  'https://www.bonappetit.com/story/recipes-bon-appetit-editors-cooked-january-2026?srsltid=AfmBOoo-XojSmp3OGbp  │
# │  DqMO_lHyl6VayzMKt9nii-iC7aRmw3EUyL8M0', 'snippet': '... without the work). Beneath the pears is a hidden       │
# │  layer of almond cream, made not from blitzing nuts in a machine, but just by whisking ...', 'position': 4},    │
# │  {'title': 'Metropolitan Market: Homepage', 'link': 'https://www.metropolitan-market.com/', 'snippet': 'Pear    │
# │  dipped in caramel, chocolate, and chopped nuts. Holiday Dessert Recipes ... Rotisserie chicken tostadas.       │
# │  Easy, Fast Rotisserie Chicken Recipes. budget- ...', 'position': 5}, {'title': 'Delicious Stir-fried Chicken   │
# │  with Cashew Nuts Recipe - Lemon8', 'link': 'https://www.lemon8-app.com/@le...                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly Chicken Stir Fry recipe for 4 people under $25, no nuts, with complet  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly Chicken Stir Fry recipe for 4 people under $25, no nuts, with    │
# │  complete ingredient lists and step-by-step instructions site:therealfooddietitians.com OR                      │
# │  site:oliverealfood.com OR site:downshiftology.com OR site:wholesomeyum.com OR site:epicurious.com', 'type':    │
# │  'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Cabbage Stir Fry (15 Minutes!) - Wholesome    │
# │  Yum', 'link':                                                                                                  │
# │  'https://www.wholesomeyum.com/cabbage-stir-fry/?srsltid=AfmBOoqmTQ-PsMU_SUhmvYR9c1fGhzCGK2l_O5lqX6Bpo8JxkSj1S  │
# │  noP', 'snippet': 'Filed Under: Healthy RecipesHealthy Dinner Ideas Cabbage RecipesHealthy Chicken Recipes      │
# │  Freezer Friendly ... KETO NUTS LIST. We hate spam and ...', 'position': 1}, {'title': 'Keto Crab Cakes         │
# │  (Gluten Free, 30 Minutes!) - Wholesome Yum', 'link':                                                           │
# │  'https://www.wholesomeyum.com/recipes/easy-crab-cakes/?srsltid=AfmBOopCuYQzB7klxokCqFJOpJWMRKmO43Nl1LEX733YXL  │
# │  a8t6M9PEdP', 'snippet': '... nut-free alternative – all without sacrificing flavor or texture! ... KETO NUTS   │
# │  LIST. We hate spam and promise to keep your email address ...', 'position': 2}], 'credits': 1}                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly Chicken Stir Fry recipe for 4 people, no nuts, with complete ingredie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly Chicken Stir Fry recipe for 4 people, no nuts, with complete     │
# │  ingredient lists and step-by-step instructions site:downshiftology.com', 'type': 'search', 'num': 10,          │
# │  'engine': 'google'}, 'organic': [{'title': 'Easy Chicken Stir Fry (in 30 Minutes!) - Downshiftology', 'link':  │
# │  'https://downshiftology.com/recipes/chicken-stir-fry/', 'snippet': "This chicken stir-fry recipe is my go-to   │
# │  for a balanced dinner that's easy to make in 30 minutes! Juicy chicken breast are tossed with colorful         │
# │  vegetables", 'position': 1}, {'title': 'Teriyaki Chicken (In 20 Minutes!) | Downnshiftology -                  │
# │  Downshiftology', 'link': 'https://downshiftology.com/recipes/teriyaki-chicken/', 'snippet': "Made in just 20   │
# │  minutes with the best homemade teriyaki sauce, this teriyaki chicken is everyone's favorite stir-fry           │
# │  dinner!", 'position': 2}, {'title': 'Chicken Fajitas (Easy & Flavorful) | Downshiftology', 'link':             │
# │  'https://downshiftology.com/recipes/chicken-fajitas/', 'snippet': 'Juicy chicken breasts are seasoned and      │
# │  seared, then tossed with vibrant vegetables, and finished with a punch of fresh lime juice.', 'position': 3},  │
# │  {'title': 'Coconut Curry Chicken (Super Easy!) - Downshiftology', 'link':                                      │
# │  'https://downshiftology.com/recipes/coconut-curry-chicken/', 'snippet': 'This coconut curry chicken is one     │
# │  flavor-packed, one-pan meal! Chicken simmers in the best creamy sauce layered with curry spices.',             │
# │  'position': 4}, {'title': 'Italian Sheet Pan Chicken Breast | Downshiftology', 'link':                         │
# │  'https://downshiftology.com/recipes/italian-sheet-pan-chicken-breast/', 'snippet': 'Step one: In a small       │
# │  bowl, stir together the olive oil, Italian seasoning, garlic, paprika, salt, and black pepper to make the      │
# │  dressing.', 'position': 5}, {'title': 'Best Chicken and Rice (One Pan) - Downshiftology', 'link':              │
# │  'https://downshiftology.com/recipes/one-pan-chicken-and-rice/comment-page-4/', 'snippet': 'This one pan        │
# │  chicken and rice recipe is easy to make, shines with bright Mediter...                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"site:downshiftology.com recipes chicken stir fry complete ingredients and steps for 4 p  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'site:downshiftology.com recipes chicken stir fry complete ingredients and steps    │
# │  for 4 people under $25 no nuts', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [], 'credits':   │
# │  1}                                                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "Easy Chicken Stir Fry recipe with complete ingredients and steps for 4 people, no
# nuts, budget under $25, beginner friendly"}, {"search_query": "filetype:pdf OR inurl:recipe OR inurl:ingredients
# 'Easy Chicken Stir Fry Downshiftology complete recipe for 4 people'"}]
# Repaired JSON: [{"search_query": "Easy Chicken Stir Fry recipe with complete ingredients and steps for 4 people, no
# nuts, budget under $25, beginner friendly"}, {"search_query": "filetype:pdf OR inurl:recipe OR inurl:ingredients
# 'Easy Chicken Stir Fry Downshiftology complete recipe for 4 people'"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"Easy Chicken Stir Fry recipe with complete ingredients and steps for 4 people, no nuts  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **                                                                                                             │
# │                                                                                                                 │
# │  Here is the detailed meal plan for a **beginner-friendly Chicken Stir Fry** recipe for 4 people, adhering to   │
# │  a **$25 budget** and **no nuts** dietary restriction:                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "meal_name": "Easy Chicken Stir Fry",                                                                        │
# │    "difficulty_level": "Beginner",                                                                              │
# │    "servings": 4,                                                                                               │
# │    "researched_ingredients": [                                                                                  │
# │      "2 boneless, skinless chicken breasts (about 1.5 lbs or 680g)",                                            │
# │      "1 bell pepper (any color), sliced",                                                                       │
# │      "1 medium carrot, julienned or sliced",                                                                    │
# │      "1 small onion, sliced",                                                                                   │
# │      "2 cups broccoli florets",                                                                                 │
# │      "2 cloves garlic, minced",                                                                                 │
# │      "1 tbsp fresh ginger, grated",                                                                             │
# │      "2 tbsp soy sauce (or tamari for gluten-free)",                                                            │
# │      "1 tbsp honey or maple syrup",                                                                             │
# │      "1 tbsp rice vinegar",                                                                                     │
# │      "1 tbsp sesame oil",                                                                                       │
# │      "1 tbsp vegetable oil (for cooking)",                                                                      │
# │      "1 tsp cornstarch (mixed with 1 tbsp water)",                                                              │
# │      "1 tbsp olive oil (for drizzling)",                                                                        │
# │      "1 green onion, sliced (for garnish)",                                                                     │
# │      "Salt and pepper to taste",                                                                                │
# │      "Optional: 1 tsp red pepper flakes (for heat)"                                                             │
# │    ],                                                                                                           │
# │    "instructions": [                                                                                            │
# │      "1. **Prep the Chicken:** Cut the chicken breasts into bite-sized pieces. Season lightly with salt and     │
# │  pepper.",                                                                                                      │
# │      "2. **Cook the Chicken:** Heat 1 tbsp vegetable oil in a large skillet or wok over medium-high heat. Add   │
# │  the chicken pieces and cook until they are no longer pink inside (about 5-6 minutes). Remove the chicken from  │
# │  the skillet and set aside.",                                                                                   │
# │      "3. **Stir-Fry the Vegetables:** In the same skillet, add 1 tbsp sesame oil and heat over medium-high      │
# │  heat. Add the sliced onion, bell pepper, carrot, and broccoli. Stir-fry for about 4-5 minutes until the        │
# │  vegetables are tender-crisp.",                                                                                 │
# │      "4. **Add Aromatics:** Add minced garlic and grated ginger to the skillet, stirring for another 30         │
# │  seconds until fragrant.",                                                                                      │
# │      "5. **Combine Sauce Ingredients:** In a small bowl, mix soy sauce, honey/maple syrup, rice vinegar, and    │
# │  the cornstarch mixed with water.",                                                                             │
# │      "6. **Combine Everything:** Return the chicken to the skillet. Pour the sauce over the chicken and         │
# │  vegetables. Stir well to coat everything evenly. Cook for another 2-3 minutes until the sauce has thickened    │
# │  slightly.",                                                                                                    │
# │      "7. **Garnish and Serve:** Drizzle with olive oil, sprinkle with sliced green onions, and red pepper       │
# │  flakes if desired. Serve hot!"                                                                                 │
# │    ],                                                                                                           │
# │    "budget_notes": [                                                                                            │
# │      "Budget Breakdown (Approximate Costs):",                                                                   │
# │      "- Chicken breasts: ~$6.00",                                                                               │
# │      "- Bell pepper, onion, carrot, broccoli (a mix of fresh produce): ~$4.00",                                 │
# │      "- Soy sauce, honey, rice vinegar, sesame oil, vegetable oil, cornstarch: ~$5.00 (assuming you have some   │
# │  basics on hand)",                                                                                              │
# │      "- Optional garnishes: ~$1.00",                                                                            │
# │      "Total: ~$16.00 (well under $25 budget)"                                                                   │
# │    ],                                                                                                           │
# │    "tips": [                                                                                                    │
# │      "Use pre-cut vegetables to save time if needed.",                                                          │
# │      "Adjust the sweetness by adding more or less honey/maple syrup.",                                          │
# │      "For extra flavor, add a splash of chicken broth to the sauce."                                            │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  This recipe is perfect for beginners and ensures a delicious, balanced meal within your budget and dietary     │
# │  constraints.                                                                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 87b5d0fa-ea0d-4820-b0d9-e0d9499ba966                                                                     │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: eac447f2-391b-4435-8ca7-4dd9fce2deb2                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **                                                                                               │
# │                                                                                                                 │
# │  Here is the detailed meal plan for a **beginner-friendly Chicken Stir Fry** recipe for 4 people, adhering to   │
# │  a **$25 budget** and **no nuts** dietary restriction:                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "meal_name": "Easy Chicken Stir Fry",                                                                        │
# │    "difficulty_level": "Beginner",                                                                              │
# │    "servings": 4,                                                                                               │
# │    "researched_ingredients": [                                                                                  │
# │      "2 boneless, skinless chicken breasts (about 1.5 lbs or 680g)",                                            │
# │      "1 bell pepper (any color), sliced",                                                                       │
# │      "1 medium carrot, julienned or sliced",                                                                    │
# │      "1 small onion, sliced",                                                                                   │
# │      "2 cups broccoli florets",                                                                                 │
# │      "2 cloves garlic, minced",                                                                                 │
# │      "1 tbsp fresh ginger, grated",                                                                             │
# │      "2 tbsp soy sauce (or tamari for gluten-free)",                                                            │
# │      "1 tbsp honey or maple syrup",                                                                             │
# │      "1 tbsp rice vinegar",                                                                                     │
# │      "1 tbsp sesame oil",                                                                                       │
# │      "1 tbsp vegetable oil (for cooking)",                                                                      │
# │      "1 tsp cornstarch (mixed with 1 tbsp water)",                                                              │
# │      "1 tbsp olive oil (for drizzling)",                                                                        │
# │      "1 green onion, sliced (for garnish)",                                                                     │
# │      "Salt and pepper to taste",                                                                                │
# │      "Optional: 1 tsp red pepper flakes (for heat)"                                                             │
# │    ],                                                                                                           │
# │    "instructions": [                                                                                            │
# │      "1. **Prep the Chicken:** Cut the chicken breasts into bite-sized pieces. Season lightly with salt and     │
# │  pepper.",                                                                                                      │
# │      "2. **Cook the Chicken:** Heat 1 tbsp vegetable oil in a large skillet or wok over medium-high heat. Add   │
# │  the chicken pieces and cook until they are no longer pink inside (about 5-6 minutes). Remove the chicken from  │
# │  the skillet and set aside.",                                                                                   │
# │      "3. **Stir-Fry the Vegetables:** In the same skillet, add 1 tbsp sesame oil and heat over medium-high      │
# │  heat. Add the sliced onion, bell pepper, carrot, and broccoli. Stir-fry for about 4-5 minutes until the        │
# │  vegetables are tender-crisp.",                                                                                 │
# │      "4. **Add Aromatics:** Add minced garlic and grated ginger to the skillet, stirring for another 30         │
# │  seconds until fragrant.",                                                                                      │
# │      "5. **Combine Sauce Ingredients:** In a small bowl, mix soy sauce, honey/maple syrup, rice vinegar, and    │
# │  the cornstarch mixed with water.",                                                                             │
# │      "6. **Combine Everything:** Return the chicken to the skillet. Pour the sauce over the chicken and         │
# │  vegetables. Stir well to coat everything evenly. Cook for another 2-3 minutes until the sauce has thickened    │
# │  slightly.",                                                                                                    │
# │      "7. **Garnish and Serve:** Drizzle with olive oil, sprinkle with sliced green onions, and red pepper       │
# │  flakes if desired. Serve hot!"                                                                                 │
# │    ],                                                                                                           │
# │    "budget_notes": [                                                                                            │
# │      "Budget Breakdown (Approximate Costs):",                                                                   │
# │      "- Chicken breasts: ~$6.00",                                                                               │
# │      "- Bell pepper, onion, carrot, broccoli (a mix of fresh produce): ~$4.00",                                 │
# │      "- Soy sauce, honey, rice vinegar, sesame oil, vegetable oil, cornstarch: ~$5.00 (assuming you have some   │
# │  basics on hand)",                                                                                              │
# │      "- Optional garnishes: ~$1.00",                                                                            │
# │      "Total: ~$16.00 (well under $25 budget)"                                                                   │
# │    ],                                                                                                           │
# │    "tips": [                                                                                                    │
# │      "Use pre-cut vegetables to save time if needed.",                                                          │
# │      "Adjust the sweetness by adding more or less honey/maple syrup.",                                          │
# │      "For extra flavor, add a splash of chicken broth to the sauce."                                            │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  This recipe is perfect for beginners and ensures a delicious, balanced meal within your budget and dietary     │
# │  constraints.                                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Single meal planning completed!
# 📋 Single Meal Results:
# meal_name='Easy Chicken Stir Fry' difficulty_level='Beginner' servings=4 researched_ingredients=['2 boneless, skinless chicken breasts (about 1.5 lbs or 680g)', '1 bell pepper (any color), sliced', '1 medium carrot, julienned or sliced', '1 small onion, sliced', '2 cups broccoli florets', '2 cloves garlic, minced', '1 tbsp fresh ginger, grated', '2 tbsp soy sauce (or tamari for gluten-free)', '1 tbsp honey or maple syrup', '1 tbsp rice vinegar', '1 tbsp sesame oil', '1 tbsp vegetable oil (for cooking)', '1 tsp cornstarch (mixed with 1 tbsp water)', '1 tbsp olive oil (for drizzling)', '1 green onion, sliced (for garnish)', 'Salt and pepper to taste', 'Optional: 1 tsp red pepper flakes (for heat)']

# %% [markdown]
# ### Creating Our Shopping Organization Agent
#
# Now that we have a meal planner that can research recipes, we need a second specialist to transform those meal plans into organized shopping lists. This is where our **Shopping Organizer** agent comes in.
#
# **Why do we need a separate shopping organizer?**
# - **Specialization**: While the meal planner focuses on recipes and cooking, the shopping organizer specializes in store logistics and efficient shopping
# - **Store Knowledge**: This agent understands how grocery stores are organized (produce, dairy, meat sections) and can group items accordingly
# - **Quantity Management**: It can calculate proper quantities for different serving sizes and ensure nothing is forgotten
#
# **Key Features of Our Shopping Organizer:**
# - **No External Tools**: Unlike the meal planner, this agent doesn't need web search - it works with the meal plan data internally
# - **Store Section Expertise**: Groups items by where you'll find them in the store (produce, dairy, meat, pantry)
# - **Quantity Calculation**: Ensures proper amounts for the specified number of servings
# - **Budget Awareness**: Considers the overall budget when organizing the shopping list

# %%
shopping_organizer = Agent(
    role="Shopping Organizer", 
    goal="Organize grocery lists by store sections efficiently",
    backstory="An experienced shopper who knows how to organize lists for quick store trips and considers dietary restrictions.",
    tools=[],
    llm=llm,
    verbose=False
)

# %% [markdown]
# ### Defining the Shopping Organization Task
#
# The shopping task is where we connect our meal planning output to our shopping organization needs. This task takes the researched meal plan and transforms it into a practical shopping list.
#
# **Key Elements of the Shopping Task:**
# - **Context Dependency**: Uses `context=[meal_planning_task]` to access the meal planner's output
# - **Pydantic Output**: Uses `output_pydantic=GroceryShoppingPlan` to ensure structured, validated output
# - **Store Organization**: Groups ingredients by store sections for efficient shopping
# - **Budget Integration**: Keeps track of costs and stays within the specified budget
#
# **The Power of Context in CrewAI:**
# When we set `context=[meal_planning_task]`, the shopping organizer can access all the research and ingredients found by the meal planner. This creates a seamless workflow where each agent builds upon the previous agent's work.

# %%
shopping_task = Task(
    description=(
        "Organize the ingredients from the '{meal_name}' meal plan into a grocery shopping list. "
        "Group items by store sections and estimate quantities for {servings} people. "
        "Consider dietary restrictions: {dietary_restrictions} and cooking skill: {cooking_skill}. "
        "Stay within budget: {budget}."
    ),
    expected_output="An organized shopping list grouped by store sections with quantities and prices.",
    agent=shopping_organizer,
    context=[meal_planning_task],
    output_pydantic=GroceryShoppingPlan,
    output_file="shopping_list.json"
)

# %% [markdown]
# ### Building Our Two-Agent Grocery Crew
#
# Now we're ready to create our first multi-agent workflow. This crew combines both the meal planner and shopping organizer to create a complete meal-to-shopping-list pipeline.
#
# **How Multi-Agent Workflows Work:**
# 1. **Sequential Processing**: The `Process.sequential` ensures agents work in order - meal planning first, then shopping organization
# 2. **Data Flow**: The shopping organizer automatically receives the meal planner's output through the task context
# 3. **Structured Output**: The final result follows our `GroceryShoppingPlan` Pydantic model for consistent formatting
#
# **Benefits of This Approach:**
# - **Separation of Concerns**: Each agent has a specific role and expertise
# - **Reusability**: We can swap out agents or add new ones without changing the overall workflow
# - **Reliability**: Pydantic ensures our output is always properly structured

# %%
two_agent_grocery_crew = Crew(
    agents=[meal_planner, shopping_organizer],  # Both agents
    tasks=[meal_planning_task, shopping_task],   # Both tasks
    process=Process.sequential,
    verbose=True
)

# Run the complete crew (this will do BOTH meal planning AND shopping)
shopping_result = two_agent_grocery_crew.kickoff(
    inputs={
        "meal_name": "Chicken Stir Fry",
        "servings": 4,
        "budget": "$25",                           
        "dietary_restrictions": ["no nuts"],      
        "cooking_skill": "beginner"               
    }
)

# Print the shopping results
print("✅ Complete meal planning + shopping completed!")
print("📋 Shopping Results:")
print(shopping_result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: dc66c37d-93f7-4b6c-a062-7d3e3cce286a                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Task: Search for the best 'Chicken Stir Fry' recipe for 4 people within a $25 budget. Consider dietary         │
# │  restrictions: ['no nuts'] and cooking skill level: beginner. Find recipes that match the skill level and       │
# │  provide complete ingredient lists with quantities.                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "best beginner-friendly Chicken Stir Fry recipe for 4 people no nuts under $25
# with full ingredient list and instructions"}, {"search_query": "easy Chicken Stir Fry recipes with ingredient
# quantities for 4 servings no nuts budget under $25"}, {"search_query": "Cheap Chicken Stir Fry recipes with
# step-by-step instructions for beginners, no nuts, ingredient quantities for 4"}]
# Repaired JSON: [{"search_query": "best beginner-friendly Chicken Stir Fry recipe for 4 people no nuts under $25
# with full ingredient list and instructions"}, {"search_query": "easy Chicken Stir Fry recipes with ingredient
# quantities for 4 servings no nuts budget under $25"}, {"search_query": "Cheap Chicken Stir Fry recipes with
# step-by-step instructions for beginners, no nuts, ingredient quantities for 4"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"best beginner-friendly Chicken Stir Fry recipe for 4 people no nuts under $25 with ful  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best easy Chicken Stir Fry recipe for 4 people no nuts budget under $25 with full ingre  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best easy Chicken Stir Fry recipe for 4 people no nuts budget under $25 with full  │
# │  ingredient list and step-by-step instructions', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic':   │
# │  [{'title': 'Easy Chicken Stir Fry - The Real Food Dietitians', 'link':                                         │
# │  'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': "... Nut-free GR Grain-Free DF Dairy-Free P  │
# │  Paleo. Sweet, savory, and tangy, this chicken stir fry is an easy recipe with a quick cook time. It's ...",    │
# │  'position': 1}, {'title': 'Chicken Stir Fry - Wholesome Yum', 'link':                                          │
# │  'https://www.wholesomeyum.com/chicken-stir-fry/?srsltid=AfmBOoo-jvJDw0alFKoh6Zi61jcr76OMW38nvBeSvIkEnsLDAXzT2  │
# │  sJo', 'snippet': '... Nut-Free OptionPaleo Option Asian. Maya Krampf in her kitchen. ... KETO NUTS LIST. We    │
# │  hate spam and promise to keep your email address ...', 'position': 2}, {'title': 'Easy Chicken Stir Fry | 20   │
# │  Minute Meal - Olive Real Food', 'link': 'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/',     │
# │  'snippet': '... Nut-Free Granola · Homemade Granola Recipe Guide · Perfect Blueberry ... Once the chicken is   │
# │  fully cooked you can either throw your veggies on top ...', 'position': 3}, {'title': 'Fast & Easy Chicken     │
# │  Stir Fry with Vegetables Recipe (nut-free)', 'link':                                                           │
# │  'https://nutfreewok.com/chicken-stir-fry-vegetables-recipe/', 'snippet': 'This recipe is free of peanuts,      │
# │  tree nuts, egg, fish, shellfish, and milk as written. If allergic to wheat, be sure to use a gluten-free       │
# │  ...', 'position': 4}, {'title': 'Ten-Minute Stir-Fried Chicken with Nuts Recipe - Epicurious', 'link':         │
# │  'https://www.epicurious.com/recipes/food/views/ten-minute-stir-fried-chicken-with-nuts-386659', 'snippet':     │
# │  'Stir in the nuts and the hoisin sauce. Cook for about 15 seconds ... NutCashewMainDinnerDairy FreeQuickEasy5  │
# │  Ingredients or FewerCookbooks.', 'position': 5}, {'title': 'Chicken and Cashew Stir-Fry Recipe in 20 Minutes   │
# │  | TikTok', 'link': 'https://www.tiktok.com/@stephcooksstuff/video/75253007629...                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient list wit  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient     │
# │  list with quantities, step-by-step instructions, beginner-friendly, cost under $25', 'type': 'search', 'num':  │
# │  10, 'engine': 'google'}, 'organic': [{'title': 'Easy Chicken Stir Fry - The Real Food Dietitians', 'link':     │
# │  'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': 'Find the ingredient list with exact         │
# │  measurements in the recipe card below. ... Dietary. Dairy-FreeEgg-FreeGluten-freeGrain-FreeHigh ProteinNut-    │
# │  ...', 'position': 1}, {'title': 'Chicken Stir Fry - Wholesome Yum', 'link':                                    │
# │  'https://www.wholesomeyum.com/chicken-stir-fry/?srsltid=AfmBOoo92yCY41160vqS2DOFpkZZqQRyvfCIuhapL7n2DIiW5vcHG  │
# │  Km4', 'snippet': '... Under 30 Minutes Dairy-Free OptionHigh ProteinKetoKid FriendlyNut-Free OptionPaleo       │
# │  Option Asian. Maya Krampf in her kitchen. About Maya ...', 'position': 2}, {'title': 'Easy Chicken Stir Fry |  │
# │  20 Minute Meal - Olive Real Food', 'link': 'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/',  │
# │  'snippet': '... Nut-Free Granola · Homemade Granola Recipe Guide · Perfect Blueberry ... Alright, so there is  │
# │  a little strategy to consider when making this Easy ...', 'position': 3}, {'title': 'Chicken and Cashew        │
# │  Stir-Fry Recipe in 20 Minutes | TikTok', 'link':                                                               │
# │  'https://www.tiktok.com/@stephcooksstuff/video/7525300762943982856?lang=en', 'snippet': 'This no-bake tart is  │
# │  a dreamy combo of sweet, salty and spicy. You can customise it your way with nuts, citrus, berries or just     │
# │  leave it pure ...', 'position': 4}, {'title': '[deleted by user] : r/EatCheapAndHealthy - Reddit', 'link':     │
# │  'https://www.reddit.com/r/EatCheapAndHealthy/comments/4lbg9e/deleted_by_user/', 'snippet': "I'd really         │
# │  recommend you try this stir fry, super healthy, super cheap, and only a few ingredients. ... Stronger flavor,  │
# │  no nuts or dairy. 53. 66 ...", 'position': 5}, {'title': 'Easy 10 Minute Keto Chinese Chicken (Nut Free And    │
# │  Gluten Free)', 'link': 'https://www.youtube....                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient list wit  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient     │
# │  list with quantities, step-by-step instructions, beginner-friendly, cost breakdown, and total time under 30    │
# │  minutes', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Easy Chicken Stir Fry -     │
# │  The Real Food Dietitians', 'link': 'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': "...      │
# │  Nut-free GR Grain-Free DF Dairy-Free P Paleo. Sweet, savory, and tangy, this chicken stir fry is an easy       │
# │  recipe with a quick cook time. It's ...", 'position': 1}, {'title': 'Easy Chicken Stir Fry | 20 Minute Meal -  │
# │  Olive Real Food', 'link': 'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/', 'snippet': '...   │
# │  Nut-Free Granola · Homemade Granola Recipe Guide · Perfect Blueberry ... You CAN create simple, healthy, and   │
# │  delicious meals in a short amount of ...', 'position': 2}, {'title': 'Satay Chicken Stir-Fry Recipe in 30      │
# │  Minutes! | Eat, Little Bird', 'link': 'https://eatlittlebird.com/satay-chicken-stir-fry/', 'snippet': '1       │
# │  handful unsalted cashew nuts, optional; spring onions, (scallions) finely sliced; coriander, (cilantro)        │
# │  finely chopped. To Serve. Steamed Jasmine Rice ...', 'position': 3}, {'title': '[PDF] How To Make Chicken      │
# │  Stir Fry', 'link':                                                                                             │
# │  'https://www1.stjameswinery.com/Resources/VU4AtR/5S9105/how_to__make__chicken_stir-fry.pdf', 'snippet':        │
# │  'While soy sauce and garlic are staples, feel free to experiment by adding ingredients like fish sauce, fresh  │
# │  herbs (cilantro, basil), or nuts ( ...', 'position': 4}, {'title': 'Chicken and Cashew Stir-Fry Recipe in 20   │
# │  Minutes | TikTok', 'link': 'https://www.tiktok.com/@stephcooksstuff/video/7525300762943982856?lang=en',        │
# │  'snippet': 'This no-bake tart is a dreamy combo of sweet, salty and spicy. You can customise it your way with  │
# │  nuts, citrus, berries or just leave it pure ...', 'position': 5}, {'title': 'Chicken Stir Fry with Veggies     │
# │  and Garlic Sauce {Paleo, Whole30}', 'link': 'https:/...                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"detailed budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'detailed budget-friendly chicken stir fry recipe for 4 people, no nuts, full       │
# │  ingredient list with quantities, step-by-step instructions, beginner-friendly, cost breakdown, and total time  │
# │  under 30 minutes site:wholesomeyum.com', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic':          │
# │  [{'title': 'Egg Roll In A Bowl (Easy 15-Minute Dinner) - Wholesome Yum', 'link':                               │
# │  'https://www.wholesomeyum.com/egg-roll-in-a-bowl/?srsltid=AfmBOoosf0066MZwLRS8ZTRmgkBz781SRo7flCfRQJM8yp1v2UC  │
# │  HfV7z', 'snippet': 'This egg roll in a bowl recipe uses simple basics like pork, cabbage, garlic & ginger. An  │
# │  easy shortcut makes it a 15-minute low carb dinner!', 'position': 1}, {'title': 'Keto Sloppy Joes - Wholesome  │
# │  Yum', 'link':                                                                                                  │
# │  'https://www.wholesomeyum.com/keto-sloppy-joes/?srsltid=AfmBOoruAB2JN03VUfOnjkI9cZgfL4SEPmRsvUxtXHXegZcejgK4_  │
# │  25a', 'snippet': 'Under 30 Minutes. By Ingredient. Almond Flour · Avocado · Chicken ... For full instructions  │
# │  with amounts and temperatures, see the recipe card.', 'position': 2}, {'title': 'Chipotle Keto Bowl (20        │
# │  Minutes) - Wholesome Yum', 'link':                                                                             │
# │  'https://www.wholesomeyum.com/keto-burrito-bowl/?srsltid=AfmBOopU0vp_Ywo_j3X-h8lHZXaw7uBeHBl6WovpY_ln75S0b7E0  │
# │  iJHt', 'snippet': "Make your own Chipotle keto bowl at home in just 20 minutes! It's loaded with tender steak  │
# │  and fresh toppings, and easy to customize.", 'position': 3}, {'title': 'Keto Cornbread (Low Carb & Easy) -     │
# │  Wholesome Yum', 'link':                                                                                        │
# │  'https://www.wholesomeyum.com/low-carb-keto-cornbread-recipe/?srsltid=AfmBOorYxwIugubWFiVAm2VOpzyJz80guy8FRbU  │
# │  ocmt_ir5GHGCg3Rj_', 'snippet': 'I have step-by-step photos here to help you visualize the recipe. For full     │
# │  instructions with amounts and temperatures, see the recipe card.', 'position': 4}, {'title': 'Baked Salmon     │
# │  Recipe (Easy & Flaky!) - Wholesome Yum', 'link':                                                               │
# │  'https://www.wholesomeyum.com/baked-salmon/?srsltid=AfmBOorcqdSI5_8djEzJOEBpBhiqQGcD8buhahTpyHFW4MNSqnbudnlI'  │
# │  , 'snippet': 'This easy oven baked salmon recipe is flaky, moist, a...                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient list wit  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient     │
# │  list with quantities, step-by-step instructions, beginner-friendly, cost breakdown, and total time under 30    │
# │  minutes site:therealfooddietitians.com', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic':          │
# │  [{'title': 'Sheet Pan Chicken With Roasted Vegetables', 'link':                                                │
# │  'https://therealfooddietitians.com/one-pan-roasted-chicken-and-vegetables/', 'snippet': 'This dinner is ready  │
# │  in under an hour and has a prep time of only 15 minutes. ... Find the ingredient list with exact measurements  │
# │  in the recipe ...', 'position': 1}, {'title': 'Lemon Chicken Piccata (30-Minute Skillet Dinner)', 'link':      │
# │  'https://therealfooddietitians.com/skillet-chicken-piccata/', 'snippet': 'Ready in 30 minutes, this chicken    │
# │  piccata is the perfect weeknight dinner. The juicy, pan-seared chicken is finished with a bright, silky        │
# │  lemon-caper sauce', 'position': 2}, {'title': 'Healthy Sweet and Sour Chicken (Full Of Veggies, Lower In       │
# │  Sugar)', 'link': 'https://therealfooddietitians.com/healthy-sweet-and-sour-chicken/', 'snippet': 'A delicious  │
# │  and healthy Sweet and Sour Chicken recipe that takes less than 20 minutes of prep time, featuring a homemade   │
# │  lower-sugar sauce.', 'position': 3}, {'title': 'The Best Ground Beef Stir Fry Recipe - The Real Food           │
# │  Dietitians', 'link': 'https://therealfooddietitians.com/ground-beef-stir-fry/', 'snippet': 'This high-protein  │
# │  stir-fry is stove-to-table ready in just under 30 minutes! It makes for a delicious, flavorful, affordable,    │
# │  and vibrant meal that everyone is ...', 'position': 4}, {'title': 'Easy Indian Butter Chicken Recipe - The     │
# │  Real Food Dietitians', 'link': 'https://therealfooddietitians.com/indian-butter-chicken/', 'snippet': "This    │
# │  Indian butter chicken recipe is my delicious and easy-to-make version of the classic murgh makhani dish. It's  │
# │  the perfect balance of spice and flavor.", 'position': 5}, {'title': 'Cheesy Chicken and Rice Casserole - The  │
# │  ...                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient list wit  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient     │
# │  list with quantities, step-by-step instructions, beginner-friendly, cost breakdown, and total time under 30    │
# │  minutes site:oliverealfood.com', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [], 'credits':   │
# │  1}                                                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient list wit  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'budget-friendly chicken stir fry recipe for 4 people, no nuts, full ingredient     │
# │  list with quantities, step-by-step instructions, beginner-friendly, cost breakdown, total time under 30        │
# │  minutes, detailed recipe', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Easy       │
# │  Chicken Stir Fry - The Real Food Dietitians', 'link': 'https://therealfooddietitians.com/chicken-stir-fry/',   │
# │  'snippet': "... Nut-free GR Grain-Free DF Dairy-Free P Paleo. Sweet, savory, and tangy, this chicken stir fry  │
# │  is an easy recipe with a quick cook time. It's ...", 'position': 1}, {'title': 'Chicken Stir Fry - Wholesome   │
# │  Yum', 'link':                                                                                                  │
# │  'https://www.wholesomeyum.com/chicken-stir-fry/?srsltid=AfmBOorjrNYNjdYz0d-uF7_xqMHXE4tgYF-73Xi8GqTMCV_qttLAo  │
# │  8q8', 'snippet': '... Under 30 Minutes Dairy-Free OptionHigh ProteinKetoKid FriendlyNut-Free OptionPaleo       │
# │  Option Asian. Maya Krampf in her kitchen. About Maya ...', 'position': 2}, {'title': 'Chicken Stir Fry with    │
# │  Veggies and Garlic Sauce {Paleo, Whole30}', 'link':                                                            │
# │  'https://www.paleorunningmomma.com/chicken-stir-fry-garlic-sauce-paleo-whole30/', 'snippet': 'Jump to Recipe.  │
# │  Whole 30 Nut Free Egg Free No Added Sugar. This delicious post was sponsored by Nakano Natural Rice Vinegar    │
# │  and all opinions ...', 'position': 3}, {'title': 'Easy Chicken Stir Fry | 20 Minute Meal - Olive Real Food',   │
# │  'link': 'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/', 'snippet': '... Nut-Free Granola ·  │
# │  Homemade Granola Recipe Guide · Perfect Blueberry ... You CAN create simple, healthy, and delicious meals in   │
# │  a short amount of ...', 'position': 4}, {'title': 'Chicken Stir Fry Recipe - YouTube', 'link':                 │
# │  'https://www.youtube.com/watch?v=gL23b2HPwjk', 'snippet': 'In this video, we are going to talk about How To    │
# │  Make Quick and Easy Chicken Stir Fry. This Chicken Stir Fry Recipe for dinner is one of ...', 'position': 5},  │
# │  {'title': 'Easy Chicken Stir-Fry - Additive Free Lifestyle', 'link': 'https://additivefreelifestyle.com/re...  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Thought: I will focus on the recipe from "The Real Food Dietitians" and "Wholesome Yum" as they seem  │
# │  to provide detailed, budget-friendly, and nut-free recipes suitable for beginners. I will extract the full     │
# │  ingredient list, quantities, and step-by-step instructions to ensure they fit the criteria of a $25 budget, 4  │
# │  servings, and no nuts.                                                                                         │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"full ingredient list with quantities and step-by-step instructions for The Real Food Di  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'full ingredient list with quantities and step-by-step instructions for The Real    │
# │  Food Dietitians Chicken Stir Fry recipe', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic':         │
# │  [{'title': 'Easy Chicken Stir Fry - The Real Food Dietitians', 'link':                                         │
# │  'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': "This isn't the full list of ingredients,    │
# │  just a few notes ... Find the ingredient list with exact measurements in the recipe card below.", 'position':  │
# │  1}, {'title': 'Stir Fry Noodles with Chicken (Gluten Free Option and Veggie-Filled)', 'link':                  │
# │  'https://therealfooddietitians.com/stir-fry-noodles/', 'snippet': 'Ready in just 30 minutes, these Stir Fry    │
# │  Noodles are packed with veggies, fiber, and protein. Gluten-free and vegan option. Serves 5.', 'position':     │
# │  2}, {'title': 'The Real - Facebook', 'link':                                                                   │
# │  'https://www.facebook.com/therealfooddietitians/photos/chicken-stir-fry-%EF%B8%8Fhttpstherealfooddietitiansco  │
# │  mchicken-stir-frysweet-savory-and-/1480589024072110/', 'snippet': "A family-favorite, it's a naturally         │
# │  gluten-free chicken recipe that's high in protein, easy to customize, and great for meal prep. Zineta ...",    │
# │  'position': 3}, {'title': 'Chicken Stir Fry | Punchfork', 'link':                                              │
# │  'https://www.punchfork.com/recipe/Chicken-Stir-Fry-The-Real-Food-Dietitians', 'snippet': 'Ingredients ; 1 lb   │
# │  boneless skinless chicken breasts, cut into thin strips ; 2 bell peppers, sliced into thin strips ; 1 cup      │
# │  snap peas or snow peas ; 3 green onions ...', 'position': 4}, {'title': 'Chicken Stir-Fry Fry 30 Minute        │
# │  Dinner - Instagram', 'link': 'https://www.instagram.com/reel/DJrGa6QtKsc/?hl=en', 'snippet': 'Ingredients For  │
# │  the Chicken & Vegetables: 3 boneless chicken breasts, diced into 1-inch pieces ½ tsp salt ½ tsp pepper 2 tbsp  │
# │  olive oil ( ...', 'position': 5}, {'title': 'Chicken Stir Fry - YouTube', 'link':                              │
# │  'https://www.youtube.com/watch?v=9tOnhDIuZ88', 'snippet': '... Full Recipe:                                    │
# │  https://therealfooddietitians.com/chicken-stir-fry ... Real ...                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"The Real Food Dietitians Chicken Stir Fry full recipe with ingredient quantities and st  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'The Real Food Dietitians Chicken Stir Fry full recipe with ingredient quantities   │
# │  and step-by-step instructions', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Easy  │
# │  Chicken Stir Fry', 'link': 'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': "Sweet, savory,   │
# │  and tangy, this chicken stir fry is an easy recipe with a quick cook time. It's faster and more budget         │
# │  friendly than takeout.", 'position': 1}, {'title': 'The Real - Facebook', 'link':                              │
# │  'https://www.facebook.com/therealfooddietitians/photos/chicken-stir-fry-%EF%B8%8Fhttpstherealfooddietitiansco  │
# │  mchicken-stir-frysweet-savory-and-/1480589024072110/', 'snippet': 'Chicken Stir Fry ⭐️                         │
# │  https://therealfooddietitians.com/chicken-stir-fry/ Sweet, savory, and tangy, this chicken stir fry is an      │
# │  easy recipe ...', 'position': 2}, {'title': 'Chicken Stir Fry - YouTube', 'link':                              │
# ...
# │      {                                                                                                          │
# │        "section_name": "Pantry",                                                                                │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Low-sodium soy sauce",                                                                      │
# │            "quantity": "1 small bottle (or buy a small 8 oz bottle)",                                           │
# │            "estimated_price": "$2.50",                                                                          │
# │            "category": "Condiments"                                                                             │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Chicken broth (low-sodium)",                                                                │
# │            "quantity": "1 small carton (or use bouillon)",                                                      │
# │            "estimated_price": "$1.50",                                                                          │
# │            "category": "Broth"                                                                                  │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Honey (or maple syrup)",                                                                    │
# │            "quantity": "Small bottle (or 1 small bottle of maple syrup)",                                       │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "Sweetener"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Rice vinegar",                                                                              │
# │            "quantity": "Small bottle (or sub apple cider vinegar)",                                             │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "Condiments"                                                                             │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Cornstarch",                                                                                │
# │            "quantity": "Small box (or buy a small bag)",                                                        │
# │            "estimated_price": "$1.00",                                                                          │
# │            "category": "Baking"                                                                                 │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Sesame oil (optional)",                                                                     │
# │            "quantity": "Small bottle",                                                                          │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "Condiments"                                                                             │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$13.00"                                                                              │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Baking/Dry Goods",                                                                      │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Jasmine rice (or instant noodles)",                                                         │
# │            "quantity": "1 small bag (or 1 pack noodles)",                                                       │
# │            "estimated_price": "$2.50",                                                                          │
# │            "category": "Rice/Noodles"                                                                           │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$2.50"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Oils & Vinegars",                                                                       │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Olive oil or vegetable oil",                                                                │
# │            "quantity": "Small bottle (if you don’t have any)",                                                  │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "Cooking Oil"                                                                            │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$3.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Spices",                                                                                │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Ground black pepper",                                                                       │
# │            "quantity": "Small jar (if you don’t have any)",                                                     │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "Spices"                                                                                 │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Salt",                                                                                      │
# │            "quantity": "Small container (if you don’t have any)",                                               │
# │            "estimated_price": "$1.00",                                                                          │
# │            "category": "Spices"                                                                                 │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$3.00"                                                                               │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "shopping_tips": [                                                                                           │
# │      "Buy pre-cut chicken strips to save time (if available).",                                                 │
# │      "Check the produce section for discounted bell peppers or snap peas.",                                     │
# │      "If you don’t have jasmine rice, instant noodles work as a budget-friendly alternative.",                  │
# │      "Use a small bottle of soy sauce and rice vinegar to avoid waste.",                                        │
# │      "Skip the sesame oil if it’s not available or too expensive; the dish will still taste great.",            │
# │      "Prep all ingredients (chopping veggies, mincing garlic) before cooking to stay organized.",               │
# │      "Adjust salt and pepper to taste—taste as you cook!",                                                      │
# │      "For extra flavor, add a dash of chili flakes or a sprinkle of sesame seeds (if available).",              │
# │      "Buy chicken broth in a small carton or use low-sodium bouillon cubes to save money.",                     │
# │      "If honey is expensive, maple syrup is a great vegan substitute."                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Complete meal planning + shopping completed!
# 📋 Shopping Results:
# total_budget='$24.99' meal_plans=[MealPlan(meal_name='Budget-Friendly Chicken Stir Fry (Nut-Free)', difficulty_level='Beginner', servings=4, researched_ingredients=['1.5 lbs boneless, skinless chicken breasts', '2 bell peppers (any color)', '1 cup snap peas or snow peas', '3 green onions', '2 cloves garlic', '1 tbsp fresh ginger', '2 tbsp olive oil (or vegetable oil)', '1/3 cup low-sodium soy sauce', '1/4 cup chicken broth', '2 tbsp honey (or maple syrup)', '1 tbsp rice vinegar', '1 tsp cornstarch (for slurry)', '2 tbsp water (for slurry)', '1 tsp sesame oil (optional)', '1 tsp ground black pepper', '1 tsp salt', '1 cup cooked jasmine rice or noodles (optional)'])] shopping_sections=[ShoppingCategory(section_name='Produce', items=[GroceryItem(name='Bell peppers (2, mixed colors)', quantity='2', estimated_price='$2.50', category='Vegetables'), GroceryItem(name='Snap peas or snow peas (1 lb bag)', quantity='1 lb', estimated_price='$2.00', category='Vegetables'), GroceryItem(name='Green onions (1 bunch)', quantity='1 bunch (~3 stalks)', estimated_price='$0.75', category='Herbs/Onions'), GroceryItem(name='Garlic (1 head)', quantity='1 head', estimated_price='$0.50', category='Herbs/Onions'), GroceryItem(name='Fresh ginger (small knob)', quantity='1 tbsp (small knob)', estimated_price='$0.30', category='Herbs/Onions')], estimated_total='$6.05'), ShoppingCategory(section_name='Meat/Deli', items=[GroceryItem(name='Boneless, skinless chicken breasts', quantity='1.5 lbs', estimated_price='$6.00', category='Chicken')], estimated_total='$6.00'), ShoppingCategory(section_name='Pantry', items=[GroceryItem(name='Low-sodium soy sauce', quantity='1 small bottle (or buy a small 8 oz bottle)', estimated_price='$2.50', category='Condiments'), GroceryItem(name='Chicken broth (low-sodium)', quantity='1 small carton (or use bouillon)', estimated_price='$1.50', category='Broth'), GroceryItem(name='Honey (or maple syrup)', quantity='Small bottle (or 1 small bottle of maple syrup)', estimated_price='$3.00', category='Sweetener'), GroceryItem(name='Rice vinegar', quantity='Small bottle (or sub apple cider vinegar)', estimated_price='$2.00', category='Condiments'), GroceryItem(name='Cornstarch', quantity='Small box (or buy a small bag)', estimated_price='$1.00', category='Baking'), GroceryItem(name='Sesame oil (optional)', quantity='Small bottle', estimated_price='$3.00', category='Condiments')], estimated_total='$13.00'), ShoppingCategory(section_name='Baking/Dry Goods', items=[GroceryItem(name='Jasmine rice (or instant noodles)', quantity='1 small bag (or 1 pack noodles)', estimated_price='$2.50', category='Rice/Noodles')], estimated_total='$2.50'), ShoppingCategory(section_name='Oils & Vinegars', items=[GroceryItem(name='Olive oil or vegetable oil', quantity='Small bottle (if you don’t have any)', estimated_price='$3.00', category='Cooking Oil')], estimated_total='$3.00'), ShoppingCategory(section_name='Spices', items=[GroceryItem(name='Ground black pepper', quantity='Small jar (if you don’t have any)', estimated_price='$2.00', category='Spices'), GroceryItem(name='Salt', quantity='Small container (if you don’t have any)', estimated_price='$1.00', category='Spices')], estimated_total='$3.00')] shopping_tips=['Buy pre-cut chicken strips to save time (if available).', 'Check the produce section for discounted bell peppers or snap peas.', 'If you don’t have jasmine rice, instant noodles work as a budget-friendly alternative.', 'Use a small bottle of soy sauce and rice vinegar to avoid waste.', 'Skip the sesame oil if it’s not available or too expensive; the dish will still taste great.', 'Prep all ingredients (chopping veggies, mincing garlic) before cooking to stay organized.', 'Adjust salt and pepper to taste—taste as you cook!', 'For extra flavor, add a dash of chili flakes or a sprinkle of sesame seeds (if available).', 'Buy chicken broth in a small carton or use low-sodium bouillon cubes to save money.', 'If honey is expensive, maple syrup is a gre ...

# %% [markdown]
# ### Adding Financial Intelligence with Budget Advisor Agent
#
# Our meal planning and shopping organization is great, but we need someone to watch the budget and provide money-saving advice. Enter our **Budget Advisor** - the financial expert of our grocery team.
#
# **Why Add a Budget Advisor?**
# - **Cost Control**: Ensures the shopping plan stays within budget limits
# - **Price Research**: Uses web search to find current prices and deals
# - **Smart Alternatives**: Suggests cheaper ingredient substitutions when needed
# - **Money-Saving Tips**: Provides practical advice for reducing grocery costs
#
# **Budget Advisor's Unique Features:**
# - **Web Search Access**: Uses `SerperDevTool()` to research current prices and deals
# - **Context Awareness**: Has access to both meal planning and shopping organization results
# - **Practical Focus**: Provides actionable advice rather than just price estimates

# %%
budget_advisor = Agent(
    role="Budget Advisor",
    goal="Provide cost estimates and money-saving tips",
    backstory="A budget-conscious shopper who helps families save money on groceries while respecting dietary needs.",
    tools=[SerperDevTool()],
    llm=llm,
    verbose=False
)

# %% [markdown]
# ### Defining the Budget Analysis Task
#
# The budget task is our financial checkpoint - it takes the complete shopping plan and adds cost analysis, budget verification, and money-saving recommendations.
#
# **What Makes This Task Special:**
# - **Multiple Context Sources**: Uses `context=[meal_planning_task, shopping_task]` to access both previous outputs
# - **Financial Analysis**: Calculates total costs and compares against budget limits
# - **Alternative Suggestions**: Provides cheaper ingredient options when budget is tight
# - **Practical Tips**: Offers real-world money-saving strategies
#
# **The Context Chain:**
# By now, our budget advisor has access to:
# 1. Original meal research from the meal planner
# 2. Organized shopping lists from the shopping organizer
# 3. Current price data from web searches
#
# This creates a comprehensive understanding of the entire grocery shopping scenario.

# %%
budget_task = Task(
    description=(
        "Analyze the shopping plan for '{meal_name}' serving {servings} people. "
        "Ensure total cost stays within {budget}. Consider dietary restrictions: {dietary_restrictions}. "
        "Provide practical money-saving tips and alternative ingredients if needed to meet budget."
    ),
    expected_output="A complete shopping guide with detailed prices, budget analysis, and money-saving tips.",
    agent=budget_advisor,
    context=[meal_planning_task, shopping_task],
    output_file="shopping_guide.md"
)

# %% [markdown]
# ###  Using YAML with CrewAI - Food Leftover Agent and Task
#
# ####  What is YAML?
#
# **YAML** (YAML Ain’t Markup Language) is a lightweight, human-readable format for structuring data. It is widely used in configuration files because it:
#
# - Is easy to read and write.
# - Supports nested data structures (for example, lists, dictionaries).
# - Keeps logic separate from code, ideal for configuration.
#
# ####  Why Use YAML with CrewAI?
#
# CrewAI supports YAML-based configuration for defining:
# - Agents
# - Tasks
# - Crew processes
#
# This allows you to:
# - Quickly iterate on agent/task logic without modifying Python code.
# - Enable team collaboration (even with non-developers).
# - Prepare workflows for production deployment.
#
# #### What Can You Define in YAML?
#
# In YAML you can define te following:
#
# - **Agents**: Roles, goals, backstories, tools, verbosity, and more
# - **Tasks**: Task descriptions, expected outputs, assigned agents, and dependencies
# - **Crew**: The execution flow (for example, `sequential`, `hierarchical`)
#
# #### YAML Example: Meal Planning Crew
#
# #### `agents.yaml`
# ![image (1).png](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/K-z4IjZnpV2pnhiAGpSvmw/image%20-1-.png)
#
# #### `tasks.yaml`
# ![image (2).png](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/HJ7axigzuQu8tdRR4UQMCg/image%20-2-.png)

# %% [markdown]
# Here, we have already created a YAML file for food leftover agent and task for your convenience. You can download it using below code.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/-5NXnHGkX1WG81tqE8kSTg/agents.yaml"
urllib.request.urlretrieve(url, "agents.yaml")
print("agents.yaml downloaded successfully")
# Out:
# agents.yaml downloaded successfully

# %%
url= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/7fhq1KPxi7cuqjOCBgcmXQ/tasks.yaml"
urllib.request.urlretrieve(url, "tasks.yaml")
print("tasks.yaml downloaded successfully")
# Out:
# tasks.yaml downloaded successfully

# %% [markdown]
# > On the left of your screen you can notice the file manager. In that we have the downloaded .yaml files. Double-click on them to open it in the new window to see how the agent and task are configured.

# %% [markdown]
# Let's move the downloaded `agent.yaml` and `tasks.yaml` under `config` folder.

# %%
# %mkdir -p config
# %mv agents.yaml  config/agents.yaml
# %mv tasks.yaml   config/tasks.yaml
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=20803) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()

# %% [markdown]
# > Note, for convenience we already created a separate `leftover.py` which has the `CrewBase` class which we already downloaded at the beginning of the lab.

# %% [markdown]
# ### Using CrewBase and Decorators with CrewAI
#
# #### What is `@CrewBase`?
# In CrewAI, `@CrewBase` is a Python class decorator that automates the collection and wiring of your agents and tasks — especially when you're organizing your crew logic in Python, YAML or hybrid config (YAML + code). Basically, when we have the following:
#
# ```python
# from crewai.project import CrewBase
# from crewai.project.annotations import agent, task
#
# @CrewBase
# class myCrew:
#     ...
# ```
# It tells CrewAI that: This class defines the agents, tasks, and crew I want to run. Please find them automatically and wire everything together.
#
# You might think that we already defined separate Agent, Task and Crew why do we need CrewBase? We need it because this can get repetitive and hard to manage as your app grows. That’s where `@CrewBase` shines.
#
# ---
#
# #### Why use `@CrewBase` + decorators?
# - **Auto-discovers** methods decorated with @agent, @task, and @crew inside the class
# - **Loads config** automatically from YAML (if present)
# - Keeps everything **modular**, **scalable**, and **clean** for production setups
#
# ---
#
# #### Decorators overview
# - CrewAI provides several decorators that are used to mark methods within your crew class for special handling.
# | Decorator           | Marks…                                            |
# | :------------------ | :----------------------------------------------- |
# | `@CrewBase`         | The class that holds your agents & tasks         |
# | `@agent`            | A method that returns an `Agent` object          |
# | `@task`             | A method that returns a `Task` object            |
# | `@crew`             | (Optional) A method that returns a `Crew` object |
# | `@before_kickoff`   | (Optional) Runs once **before** the crew starts  |
# | `@after_kickoff`    | (Optional) Runs once **after** the crew finishes |
#
# > The **CrewBase class**, along with these decorators, automates the collection of agents and tasks, reducing the need for manual management.

# %% [markdown]
# ### How `@CrewBase` Works with YAML in This Project
#
# CrewAI's `@CrewBase` decorator works seamlessly with YAML files, pure Python, or a hybrid setup — and in our case, we're using the hybrid approach to demonstrate how it all comes together.
#
# So, what's happening here is:
# - The `@agent` method is loading the agent config from the YAML file via: `self.agents_config["leftover_manager"]` and returns an Agent object.
# - Similarly, the `@task` method does: `self.tasks_config["leftover_task"]` and returns a Task object, linked to the `leftover_manager`.
#
# In our Jupyter notebook, we import the `LeftoverCrew` class which allows us to access the Agent and Task objects that were dynamically constructed using YAML-based config.
#
# ---
#
# #### Why YAML Location Matters?
# The `@CrewBase` class (under the hood) looks for default YAML files under a `config/` directory. That’s why we needed to place our `agents.yaml` and `tasks.yaml` inside a `config/` folder — otherwise CrewAI wouldn’t find them automatically.
#
# ---
#
# #### Why We Needed a .py File?
# The @CrewBase class and its decorators such as `@agent`, `@task`, and `@crew` do not work in Jupyter notebooks due to how the CrewAI framework relies on Python’s inspection tools. What it means is CrewAI uses Python’s `inspect` module to find the file path of the class:
# ```python
# Path(inspect.getfile(cls)).parent
# ```
# This works fine when the class is defined in a regular `.py` file.
#
# But in Jupyter notebooks:
# - Classes are defined in cells, not .py files.
# - `inspect.getfile(cls)` fails because there is no real source file.
# - As a result, CrewAI cannot determine the base directory, and throws an error.
#
# To fix this, we moved the crew class into a separate `.py` file (leftover.py).

# %% [markdown]
# Here is how the `@CrewBase` class from `leftover.py` looks:
#
# ![image.png](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/36nCxdNoEA3stoy9uM5WaQ/image.png)

# %%
from leftover import LeftoversCrew

leftovers_cb = LeftoversCrew(llm=llm)
yaml_leftover_manager = leftovers_cb.leftover_manager()
yaml_leftover_task    = leftovers_cb.leftover_task()

# %% [markdown]
# > 💡 **Note:** While `@CrewBase` makes your agent/task management easier, it wraps your class behind the scenes.
# >
# > That means:
# > - You can't always use `__init__()` or pass custom objects like in normal Python classes.
# > - Testing and debugging `@CrewBase` classes inside Jupyter notebooks can be tricky due to how Jupyter handles decorators and dynamic reloading.
# >
# > 📁 For stability, define your `@CrewBase` classes in separate `.py` files instead of notebooks. This makes CrewAI's configuration loading and agent resolution work reliably.
# >
# > 🔍 See the [CrewAI documentation](https://docs.crewai.com/) for full details on how `@CrewBase` works.

# %% [markdown]
# ### Defining Our Summary Agent and Task
#
# To manage all the content generated by the agents, we will now create one final agent and its corresponding task which will gather all the content and create a detailed summary.

# %%
summary_agent = Agent(
    role="Report Compiler",
    goal="Compile comprehensive meal planning reports from all team outputs",
    backstory="A skilled coordinator who organizes information from multiple specialists into comprehensive, easy-to-follow reports.",
    tools=[],
    llm=llm,
    verbose=False
)

# %%
summary_task = Task(
    description=(
        "Compile a comprehensive meal planning report that includes:\n"
        "1. The complete recipe and cooking instructions from the meal planner\n"
        "2. The organized shopping list with prices from the shopping organizer\n"
        "3. The budget analysis and money-saving tips from the budget advisor\n"
        "4. The leftover management suggestions from the waste reduction specialist\n"
        "Format this as a complete, user-friendly meal planning guide."
    ),
    expected_output="A comprehensive meal planning guide that combines all team outputs into one cohesive report.",
    agent=summary_agent,
    context=[meal_planning_task, shopping_task, budget_task, yaml_leftover_task],
)

# %% [markdown]
# ### Assembling Our Complete Grocery Planning Team
#
# Next, we bring together all five specialists into one powerful grocery planning crew. This represents our complete end-to-end solution from meal idea to comprehensive shopping guide with zero-waste strategies.
#
# **Our Five-Agent Team:**
# 1. **Meal Planner**: Researches recipes and creates meal plans
# 2. **Shopping Organizer**: Transforms meal plans into organized shopping lists
# 3. **Budget Advisor**: Adds financial analysis and money-saving strategies
# 4. **Leftover Manager**: Minimizes food waste by suggesting creative uses for leftover ingredients
# 5. **Report Compiler**: Consolidates all outputs into one comprehensive, user-friendly guide

# %%
complete_grocery_crew = Crew(
    agents=[
        meal_planner,           
        shopping_organizer,      
        budget_advisor,         
        yaml_leftover_manager,  # YAML-based leftover manager
        summary_agent           # New summary agent
    ],
    tasks=[
        meal_planning_task,     
        shopping_task,          
        budget_task,            
        yaml_leftover_task,    # YAML-based leftover task
        summary_task            # New summary task
    ],
    process=Process.sequential,
    verbose=True
)

# %% [markdown]
# ### Executing Our Complete Grocery Planning Workflow
#
# It's now time to put our five-agent team to work! We're going to run the complete workflow with more detailed inputs to demonstrate the full capabilities of our system.
#
# **Enhanced Input Parameters:**
# - **Multiple Dietary Restrictions**: `["no nuts", "low sodium"]` shows how the system handles complex dietary needs
# - **Skill Level Consideration**: `"beginner"` ensures recipe complexity matches cooking ability
# - **Budget Constraints**: `"$25"` provides a realistic budget limit for practical planning
# - **Serving Size**: `4 people` for family meal planning
# - **Meal Focus**:`Chicken Stir Fry` as our target dish
#
# **What Happens During Execution:**
# 1. **Meal Planner** searches for beginner-friendly, nut-free, low-sodium chicken stir fry recipes
# 2. **Shopping Organizer** creates a structured shopping list organized by store sections
# 3. **Budget Advisor** analyzes costs, ensures budget compliance, and provides money-saving tips
# 4. **Leftover Manager** identifies ingredients that might result in leftovers and suggests creative bonus recipes to minimize waste and maximize the grocery budget
# 5. **Report Compiler** consolidates all outputs into one comprehensive, user-friendly guide with clear sections for easy reference
#
# The result is a comprehensive grocery shopping guide that considers all your constraints and preferences.

# %%
# Run the complete crew
complete_result = complete_grocery_crew.kickoff(
    inputs={
        "meal_name": "Chicken Stir Fry",
        "servings": 4,
        "budget": "$25",
        "dietary_restrictions": ["no nuts", "low sodium"],
        "cooking_skill": "beginner"
    }
)

print("✅ Complete meal planning with summary completed!")
print("📋 Complete Results:")
print(complete_result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 042b3515-ff3b-47a1-bf7c-ee9ba6b75c4d                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Task: Search for the best 'Chicken Stir Fry' recipe for 4 people within a $25 budget. Consider dietary         │
# │  restrictions: ['no nuts', 'low sodium'] and cooking skill level: beginner. Find recipes that match the skill   │
# │  level and provide complete ingredient lists with quantities.                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best beginner-friendly low sodium no nuts chicken stir fry recipe for 4 people under $2  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best beginner-friendly low sodium no nuts chicken stir fry recipe for 4 people     │
# │  under $25 with full ingredient list and instructions', 'type': 'search', 'num': 10, 'engine': 'google'},       │
# │  'organic': [{'title': 'Easy chicken stir fry recipe with fresh ingredients - Facebook', 'link':                │
# │  'https://www.facebook.com/groups/945531352641321/posts/1978755642652215/', 'snippet': 'Serve on a bed of rice  │
# │  or noodles, I used steamed jasmine rice. You could also toast some pine nuts, almonds, macadamias or raw       │
# │  cashews to ...', 'position': 1}, {'title': 'Easy Chicken Stir Fry | 20 Minute Meal - Olive Real Food',         │
# │  'link': 'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/', 'snippet': "... Nut-Free Granola ·  │
# │  Homemade Granola Recipe Guide · Perfect Blueberry ... Since I spend a lot of free time cooking, I decided I'd  │
# │  like to put all ...", 'position': 2}, {'title': 'Fast & Easy Chicken Stir Fry with Vegetables Recipe           │
# │  (nut-free)', 'link': 'https://nutfreewok.com/chicken-stir-fry-vegetables-recipe/', 'snippet': 'This recipe is  │
# │  free of peanuts, tree nuts, egg, fish, shellfish, and milk as written. If allergic to wheat, be sure to use a  │
# │  gluten-free ...', 'position': 3}, {'title': 'Easy 10 Minute Keto Chinese Chicken (Nut Free And Gluten Free)',  │
# │  'link': 'https://www.youtube.com/watch?v=BVW0Jkf3n8c', 'snippet': 'This video is designed to teach everyone    │
# │  how to make easy 10 minute keto Chinese chicken. This recipe is low carb, keto friendly, nut free, ...',       │
# │  'position': 4}, {'title': 'Quick and Delicious Cashew Chicken Stir Fry Recipe | TikTok', 'link':               │
# │  'https://www.tiktok.com/@kimberlys_journey/video/7494716714924428566', 'snippet': 'Air Fryer Doughnut Balls    │
# │  No Yogurt · Frozen Doughnut in Air Fryer ... Then split into 3 or 4 balls. Lay a large sheet of parchment      │
# │  paper ...', 'position': 5}, {'title': 'Ground Chicken & Vegetables Stir Fry Recipe Under 30 Minutes', 'link':  │
# │  'https://www.tiktok.com/@mallorythedietitian/video/7462093930096577838', 'snippet': 'C...                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly low sodium no nuts chicken stir fry recipe with full ingredient list,  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly low sodium no nuts chicken stir fry recipe with full ingredient  │
# │  list, quantities, and step-by-step instructions under $25 for 4 people site:allrecipes.com or                  │
# │  site:bbcgoodfood.com or site:foodnetwork.com or site:damndelicious.com or site:minimalistbaker.com', 'type':   │
# │  'search', 'num': 10, 'engine': 'google'}, 'organic': [], 'credits': 1}                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly low sodium chicken stir fry recipe for 4 people no nuts full ingredie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly low sodium chicken stir fry recipe for 4 people no nuts full     │
# │  ingredients and instructions budget under $25 site:damndelicious.net', 'type': 'search', 'num': 10, 'engine':  │
# │  'google'}, 'organic': [], 'credits': 1}                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly low sodium no nuts chicken stir fry recipe full ingredients quantitie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly low sodium no nuts chicken stir fry recipe full ingredients      │
# │  quantities instructions budget $25 for 4 people site:allrecipes.com', 'type': 'search', 'num': 10, 'engine':   │
# │  'google'}, 'organic': [{'title': '35 Cheap Chicken Recipes for Weeknight Dinners - Allrecipes', 'link':        │
# │  'https://www.allrecipes.com/cheap-chicken-recipes-8582095', 'snippet': 'From crowd-pleasing casseroles to      │
# │  simple-but-flavorful drumsticks and chicken thighs, these budget-friendly chicken dinners are perfect for      │
# │  weeknights at home.', 'position': 1}, {'title': 'We Tried 8 Kinds of Ramen–This Is the One You Should Stock    │
# │  in ...', 'link': 'https://www.allrecipes.com/best-instant-ramen-taste-test-7370078', 'snippet': 'We rounded    │
# │  up eight varieties of chicken ramen in packet and cup form, all of which are available online or in stores.    │
# │  Here are our picks, from best in show to ...', 'position': 2}, {'title': 'I Made Hundreds of Pancakes to Find  │
# │  the Best Electric Griddles', 'link': 'https://www.allrecipes.com/affiliate/best-electric-griddles/',           │
# │  'snippet': 'Essentially, electric griddles are flat-top cooking surfaces that plug into the wall, freeing up   │
# │  your stove, and can even be taken on the road.', 'position': 3}], 'credits': 1}                                │
# │                                                                                                                 │
# │                                                                                                                 │
# │  You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:          │
# │                                                                                                                 │
# │  Tool Name: Search the internet with Serper                                                                     │
# │  Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the         │
# │  internet', 'type': 'str'}}                                                                                     │
# │  Tool Description: A tool that can be used to search the internet with a search_query. Supports different       │
# │  search types: 'search' (default), 'news'                                                                       │
# │                                                                                                                 │
# │  IMPORTANT: Use the following format in your response:                                                          │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: you should always think about what to do                                                              │
# │  Action: the action to take, only one name of [Search the internet with Serper], just the name, exactly as      │
# │  it's written.                                                                                                  │
# │  Action Input: the input to the action, just a simple JSON object, enclosed in curly brac...                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly low sodium no nuts chicken stir fry recipe with full ingredients, qua  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly low sodium no nuts chicken stir fry recipe with full             │
# │  ingredients, quantities, and instructions budget under $25 for 4 people site:damndelicious.net OR              │
# │  site:minimalistbaker.com OR site:foodnetwork.com', 'type': 'search', 'num': 10, 'engine': 'google'},           │
# │  'organic': [{'title': '25 Must-Have Ingredients for a Budget Pantry', 'link':                                  │
# │  'https://www.foodnetwork.com/recipes/packages/cooking-from-the-pantry/14-musts-for-a-budget-pantry',           │
# │  'snippet': "We've done the planning for you and created a list of items that are inexpensive, versatile,       │
# │  healthy and long-lasting.", 'position': 1}, {'title': '25 Best Cheap Eats in St. Louis', 'link':               │
# │  'https://www.foodnetwork.com/restaurants/photos/best-cheap-eats-st-louis', 'snippet': 'Find out where to get   │
# │  stuffed for less in the Lou, with this cheap-eats guide to the best sandwiches, pastries, pizza, tacos, pho    │
# │  and more.', 'position': 2}, {'title': 'The Best Restaurants in Phoenix | Food Network', 'link':                │
# │  'https://www.foodnetwork.com/restaurants/photos/best-restaurants-phoenix', 'snippet': 'Find the best food in   │
# │  Phoenix, including pizzas, burritos, burgers and shockingly fresh seafood.', 'position': 3}, {'title': 'Best   │
# │  Cheap Eats Restaurants in Chicago', 'link':                                                                    │
# │  'https://www.foodnetwork.com/restaurants/photos/best-cheap-eats-restaurants-chicago', 'snippet': '... chicken  │
# │  adobo ($9) is a paragon of form; comprising fall-off-the-bone chicken pieces braised in garlic, vinegar and    │
# │  soy, all over rice. More ...', 'position': 4}], 'credits': 1}                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients quantitie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients      │
# │  quantities instructions budget under $25 site:minimalistbaker.com', 'type': 'search', 'num': 10, 'engine':     │
# │  'google'}, 'organic': [], 'credits': 1}                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner-friendly low sodium chicken stir fry recipe no nuts for 4 people with full ing  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner-friendly low sodium chicken stir fry recipe no nuts for 4 people with     │
# │  full ingredients, quantities, and step-by-step instructions budget under $25 site:allrecipes.com recipe',      │
# │  'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Stick of Butter Steak and Rice        │
# │  Recipe - Allrecipes', 'link': 'https://www.allrecipes.com/stick-of-butter-steak-and-rice-recipe-11768175',     │
# │  'snippet': 'Ingredients · 2 cups rice · 1/2 onion, thinly sliced · 8 ounces sliced baby portobello mushrooms   │
# │  · 2 (10 ounce) cans beef consomme · 1 (10 ounce) can ...', 'position': 1}, {'title': 'The 6 Best Oven          │
# │  Thermometers, According to a Chef - Allrecipes', 'link':                                                       │
# │  'https://www.allrecipes.com/affiliate/best-oven-thermometers/', 'snippet': 'A good oven thermometer can mean   │
# │  the difference between a perfectly executed dish and a disastrous result. We did the research, ...',           │
# │  'position': 2}, {'title': 'Crab Quiche Recipe - Allrecipes', 'link':                                           │
# │  'https://www.allrecipes.com/recipe/71025/crab-quiche/', 'snippet': 'Ingredients · 1 (9 inch) deep-dish frozen  │
# │  pie crust · 4 large eggs · 1 cup heavy cream · ½ teaspoon salt · ½ teaspoon ground black pepper · 3 dashes     │
# │  hot pepper sauce ...', 'position': 3}], 'credits': 1}                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# │  You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:          │
# │                                                                                                                 │
# │  Tool Name: Search the internet with Serper                                                                     │
# │  Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the         │
# │  internet', 'type': 'str'}}                                                                                     │
# │  Tool Description: A tool that can be used to search the internet with a search_query. Supports different       │
# │  search types: 'search' (default), 'news'                                                                       │
# │                                                                                                                 │
# │  IMPORTANT: Use the following format in your response:                                                          │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: you should always think about what to do                                                              │
# │  Action: the action to take, only one name of [Search the internet with Serper], just the name, exactly as      │
# │  it's written.                                                                                                  │
# │  Action Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " t...       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients quantitie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients      │
# │  quantities instructions budget under $25 site:damndelicious.net recipe', 'type': 'search', 'num': 10,          │
# │  'engine': 'google'}, 'organic': [], 'credits': 1}                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients quantitie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients      │
# │  quantities instructions budget under $25 site:https://www.food.com', 'type': 'search', 'num': 10, 'engine':    │
# │  'google'}, 'organic': [], 'credits': 1}                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"beginner low sodium no nuts chicken stir fry recipe for 4 people with full ingredients   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'beginner low sodium no nuts chicken stir fry recipe for 4 people with full         │
# │  ingredients list and step-by-step instructions under $25 site:https://www.foodnetwork.com/recipe OR            │
# │  site:https://www.eatingwell.com/recipe OR site:https://www.epicurious.com/recipe', 'type': 'search', 'num':    │
# │  10, 'engine': 'google'}, 'organic': [{'title': 'Shrimp Cauliflower Fried Rice - EatingWell', 'link':           │
# │  'https://www.eatingwell.com/recipe/276818/shrimp-cauliflower-fried-rice/', 'snippet': 'Try this shrimp         │
# │  cauliflower fried rice for a quick, healthy low-carb dinner choice that can be prepared in just 25             │
# │  minutes—ideal for busy ...', 'position': 1}], 'credits': 1}                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# │  You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:          │
# │                                                                                                                 │
# │  Tool Name: Search the internet with Serper                                                                     │
# │  Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the         │
# │  internet', 'type': 'str'}}                                                                                     │
# │  Tool Description: A tool that can be used to search the internet with a search_query. Supports different       │
# │  search types: 'search' (default), 'news'                                                                       │
# │                                                                                                                 │
# │  IMPORTANT: Use the following format in your response:                                                          │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: you should always think about what to do                                                              │
# │  Action: the action to take, only one name of [Search the internet with Serper], just the name, exactly as      │
# │  it's written.                                                                                                  │
# │  Action Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " to wrap    │
# │  keys and values.                                                                                               │
# │  Observation: the result of the action                                                                          │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  Once all necessary information is gathered, return the following format:                                       │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: I now know the final answer                                                                           │
# │  Final Answer: the final answer to the original input question                                                  │
# │  ```                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"easy low sodium chicken stir fry recipe no nuts for 4 people full ingredients quantitie  │
# │                                                                                                                 │
# ...
# │  **Uses:** Leftover chicken, veggie scraps, garlic, ginger.                                                     │
# │  **Cost:** ~$0                                                                                                  │
# │  **Instructions:**                                                                                              │
# │  1. Sauté garlic, ginger, and veggie scraps in a pot.                                                           │
# │  2. Add water and leftover chicken. Simmer for 20-30 minutes.                                                   │
# │  3. Strain and use as a base for soups or sauces.                                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Additional Tips for Leftover Management:**                                                               │
# │  - **Store properly:** Keep chicken and veggies in airtight containers in the fridge for up to 3 days or        │
# │  freeze for longer storage.                                                                                     │
# │  - **Use freezer-friendly containers:** Portion leftovers into freezer-safe containers for future meals.        │
# │  - **Repurpose veggie scraps:** Save carrot tops, onion skins, and bell pepper stems to make homemade veggie    │
# │  broth.                                                                                                         │
# │  - **Buy in bulk:** Garlic, ginger, and onions last longer than pre-minced or pre-grated versions.              │
# │  - **Meal prep:** Cook extra rice or grains to use in multiple meals.                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## **5. Sample Meal Plan Using Leftovers (Within $25 Budget)**                                                 │
# │                                                                                                                 │
# │  | Day       | Meal                     | Uses Leftover Ingredients? | Cost  |                                  │
# │  |-----------|--------------------------|----------------------------|-------|                                  │
# │  | **Day 1** | Chicken Stir Fry         | N/A                        | $19.75|                                  │
# │  | **Day 2** | Chicken & Rice Fried Rice | Yes (leftover chicken, rice, veggies) | $0.00 |                      │
# │  | **Day 3** | Chicken & Veggie Lettuce Wraps | Yes (leftover chicken, veggies) | $0.00 |                       │
# │  | **Day 4** | Veggie & Chicken Soup    | Yes (leftover chicken, veggies, rice) | $0.00 |                       │
# │  | **Day 5** | Spicy Garlic Chicken & Rice Bowl | Yes (leftover chicken, rice) | $0.00 |                        │
# │  | **Day 6** | Quick Pickled Onions & Carrots | Yes (leftover onion, carrot) | $0.00 |                          │
# │  | **Day 7** | Garlic & Ginger Chicken Stock | Yes (leftover chicken, veggies) | $0.00 |                        │
# │                                                                                                                 │
# │  **Total Cost for 7 Days:** **$19.75** (well under $25 budget).                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ## **Final Notes:**                                                                                            │
# │  - **All recipes are low-sodium and nut-free**, adhering to dietary restrictions.                               │
# │  - **No additional ingredients are needed** for most recipes—just repurpose what you have!                      │
# │  - **Budget remains under $25**, with room for optional ingredients like eggs or tofu.                          │
# │  - **Minimize waste and maximize value** by creatively using leftovers.                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  This comprehensive guide ensures you have **everything you need** to plan, shop, cook, and repurpose           │
# │  ingredients efficiently while staying within your budget!                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Complete meal planning with summary completed!
# 📋 Complete Results:
# Comprehensive Meal Planning Guide for Easy Chicken Stir Fry**
#
# ---
#
# ## **1. Recipe and Cooking Instructions**
# **Meal Name:** Easy Chicken Stir Fry
# **Difficulty Level:** Beginner
# **Servings:** 4
# **Dietary Restrictions:** No nuts, low-sodium
# **Total Estimated Cost:** **$13.00** (well under $25 budget)
#
# ### **Ingredients:**
# #### **Marinade:**
# - 3 boneless, skinless chicken breasts (or 6-8 chicken thighs)
# - 2 tbsp olive oil
# - 2 tbsp low-sodium soy sauce (or coconut aminos)
# - 1 tbsp fresh lemon juice
# - 1 tbsp honey (or maple syrup)
# - 2 cloves garlic, minced
# - 1 tsp grated fresh ginger
# - ½ tsp black pepper
#
# #### **Stir-Fry:**
# - 2 tbsp olive oil (for stir-frying)
# - 1 bell pepper, sliced
# - 1 carrot, julienned
# - 1 small onion, sliced
# - 2 cups broccoli florets
# - 1 cup snap peas (optional)
# - 2 cloves garlic, minced
# - 1 tbsp fresh ginger, grated
# - 2 tbsp low-sodium soy sauce (or coconut aminos)
# - 1 tbsp rice vinegar
# - 1 tbsp honey (or maple syrup)
# - 1 tsp sesame oil (optional)
# - ½ tsp red pepper flakes (optional)
#
# ---
#
# ### **Instructions:**
# 1. **Marinate the chicken:** Combine chicken with olive oil, low-sodium soy sauce, lemon juice, honey, minced garlic, ginger, and black pepper. Refrigerate for at least 30 minutes.
# 2. **Prepare vegetables:** Slice bell pepper, julienne carrot, slice onion, and cut broccoli into florets. Trim snap peas if using.
# 3. **Cook the chicken:** Heat 1 tbsp olive oil in a skillet over medium-high heat. Cook chicken for 5-6 minutes per side until fully done. Remove and set aside.
# 4. **Stir-fry vegetables:** In the same skillet, add another tbsp of olive oil. Stir-fry onion, bell pepper, and carrot for 3-4 minutes. Add broccoli and snap peas, stir-fry for another 3-4 minutes.
# 5. **Combine and season:** Add minced garlic and ginger, stir-fry for 30 seconds. Pour in soy sauce, rice vinegar, honey, and sesame oil. Return chicken to skillet, toss to coat, and cook for 2 more minutes. Add red pepper flakes if using.
# 6. **Serve:** Serve hot over steamed rice or quinoa, garnished with fresh cilantro if desired.
#
# ---
#
# ## **2. Organized Shopping List with Prices**
#
# ### **Total Budget Allocation: $25**
#
# #### **Meat & Poultry ($4.50 - $7.00)**
# - **Boneless, skinless chicken breasts (or thighs):** 3 lbs (~$6.00) *or* 6-8 thighs (~$4.50)
#   - *Tip:* Chicken thighs are cheaper and more flavorful.
#
# #### **Produce ($5.00 - $8.00)**
# - **1 large bell pepper:** $1.50
# - **2 medium carrots:** $0.75
# - **1 yellow onion:** $0.50
# - **1 head fresh or frozen broccoli:** $2.00 (frozen is cheaper)
# - **1 cup snap peas (optional):** $1.50
# - **1 small knob fresh ginger:** $0.75
# - **1 head fresh garlic:** $0.50
# - **1 small lemon:** $0.50
#
# #### **Pantry Staples ($7.50 - $15.50, if buying new)**
# - **Olive oil:** $3.00 (if buying new)
# - **Low-sodium soy sauce or coconut aminos:** $2.50
# - **Honey or maple syrup:** $3.00
# - **Rice vinegar:** $2.00
# - **Sesame oil (optional):** $2.50
# - **Red pepper flakes (optional):** $1.50
# - **Black pepper (if needed):** $1.00
#
# #### **Grain ($2.00)**
# - **1 lb white rice or quinoa:** $2.00
#
# #### **Optional Garnish ($0.75)**
# - **Fresh cilantro:** $0.75
#
# #### **Frozen Foods (Alternative, $2.00)**
# - **Frozen stir-fry vegetable mix:** $2.00
#
# ---
#
# ### **Estimated Total Cost Breakdown:**
# | Category               | Estimated Cost | Notes                                  |
# |------------------------|----------------|----------------------------------------|
# | **Meat**               | $4.50 - $7.00  | Thighs are cheaper.                     |
# | **Produce**            | $5.00 - $8.00  | Frozen veggies save money.             |
# | **Pantry**             | $7.50 - $15.50 | Use existing staples if possible.      |
# | **Grain**              | $2.00          | Cook extra rice for future meals.       |
# | **Optional**           | $0.75 - $7.50  | Skip optional items to stay under budget.|
# | **Total**              | **$19.75 - $33.00** | **Budget-friendly range: $19.75 (minimal options) to $25 (with some extras).** |
#
# ---
#
# ## **3. Budget Analysis and Money-Saving Tips**
#
# ### **Budget Breakdown:**
# - **Total Budget:** $25
# - **Estimated Cost (Minimal Options):** **$19.75**
# - **Remaining Budget:** **$5.25** (for optional items like sesame oil, red pepper flakes, or cilantro).
#
# ### **Money-Saving Tips:**
# 1. **Use Chicken Thighs:** Save **$1.50** compared to chicken breasts.
# 2. **Buy Frozen Veggies:** Frozen broccoli or stir-fry mixes are cheaper and last longer.
# 3. **Skip Optional Items:** Avoid sesame oil, red pepper flakes, and snap peas to stay under budget.
# 4. **Use Maple Syrup Instead of Honey:** Save **$0.50**.
# 5. **Check Pantry First:** Avoid buying olive oil, soy sauce, or spices if you already have them.
# 6. **Cook Extra Rice:** Use leftover rice in other meals like fried rice or soups.
# 7. **Shop Sales:** Look for discounted meat, veggies, or grains.
# 8. **Marinate Chicken Overnight:** Save time on cooking day.
# 9. **Use Coconut Aminos:** Lower sodium alternative to soy sauce.
# 10. **Skip Cilantro:** Use parsley or another herb if cilantro is unavailable.
#
# ---
#
# ### **Alternative Ingredients (Budget Swaps):**
# | Original               | Budget Swap               | Cost Difference | Notes                                  |
# |------------------------|---------------------------|-----------------|----------------------------------------|
# | Chicken breasts        | Chicken thighs/drumsticks  | Save $1.50      | More flavorful.                        |
# | Fresh broccoli         | Frozen broccoli           | Save $0.50      | No waste, same nutrition.              |
# | Honey                  | Maple syrup               | Save $0.50      | Cheaper and similar sweetness.         |
# | Bell pepper            | Zucchini or cabbage       | Save $1.00      | Great for stir-fry.                    |
# | Low-sodium soy sauce   | Coconut aminos            | +$1.50         | Lower sodium, but pricier. Use sparingly.|
#
# ---
#
# ## **4. Leftover Management Suggestions**
#
# ### **Leftover Ingredients from Chicken Stir Fry:**
# 1. **Chicken:** Marinated or cooked portions.
# 2. **Vegetables:** Bell pepper, carrot, onion, broccoli, snap peas.
# 3. **Pantry Staples:** Soy sauce, rice vinegar, honey/maple syrup, garlic, ginger.
# 4. **Grain:** Extra cooked rice.
#
# ---
#
# ### **Creative Ways to Use Leftovers:**
#
# #### **1. Chicken & Rice Fried Rice**
# **Uses:** Leftover chicken, rice, veggies, soy sauce, vinegar, garlic, ginger.
# **Cost:** ~$0
# **Instructions:**
# 1. Heat olive oil, sauté garlic, ginger, and leftover veggies.
# 2. Add leftover rice and leftover chicken.
# 3. Stir in soy sauce, rice vinegar, and black pepper.
# 4. Optional: Add an egg for extra protein.
#
# ---
#
# #### **2. Chicken & Veggie Lettuce Wraps**
# **Uses:** Leftover chicken, veggies, soy sauce, vinegar, garlic, ginger.
# **Cost:** ~$0
# **Instructions:**
# 1. Stir-fry leftover veggies with garlic and ginger.
# 2. Add leftover chicken and season with soy sauce and vinegar.
# 3. Serve in butter lettuce or romaine leaves.
#
# ---
#
# #### **3. Veggie & Chicken Soup**
# **Uses:** Leftover chicken, veggies, soy sauce, vinegar, garlic, ginger, extra rice.
# **Cost:** ~$0
# **Instructions:**
# 1. Sauté garlic, ginger, and veggies in a pot.
# 2. Add water or broth, leftover chicken, and soy sauce.
# 3. Simmer for 20 minutes. Optional: Add leftover rice for thickness.
#
# ---
#
# #### **4. Spicy Garlic Chicken & Rice Bowl**
# **Uses:** Leftover chicken, rice, garlic, ginger, red pepper flakes (optional).
# **Cost:** ~$0
# **Instructions:**
# 1. Stir-fry leftover chicken with garlic, ginger, and red pepper flakes.
# 2. Serve over leftover rice.
#
# ---
#
# #### **5. Quick Pickled Onions & Carrots**
# **Uses:** Leftover onion, carrot, rice vinegar, sugar/maple syrup.
# **Cost:** ~$0
# **Instructions:**
# 1. Thinly slice onion and julienne carrot.
# 2. Mix with rice vinegar, sugar/maple syrup, and water.
# 3. Let sit for 30 minutes. Use as a topping for rice bowls or wraps.
#
# ---
#
# #### **6. Garlic & Ginger Chicken Stock**
# **Uses:** Leftover chicken, veggie scraps, garlic, ginger.
# **Cost:** ~$0
# **Instructions:**
# 1. Sauté garlic, ginger, and veggie scraps in a pot.
# 2. Add water and leftover chicken. Simmer for 20-30 minutes.
# 3. Strain and use as a base for soups or sauces.
#
# ---
#
# ### **Additional Tips for Leftover Management:**
# - **Store properly:** Keep chicken and veggies in airtight containers in the fridge for up to 3 days or freeze for longer storage.
# - **Use freezer-friendly containers:** Portion leftovers into freezer-safe containers for future meals.
# - **Repurpose veggie scraps:** Save carrot tops, onion skins, and bell pepper stems to make homemade veggie broth.
# - **Buy in bulk:** Garlic, ginger, and onions last longer than pre-minced or pre-grated versions.
# - **Meal prep:** Cook extra rice or grains to use in multiple meals.
#
# ---
#
# ## **5. Sample Meal Plan Using Leftovers (Within $25 Budget)**
#
# | Day       | Meal                     | Uses Leftover Ingredients? | Cost  |
# |-----------|--------------------------|----------------------------|-------|
# | **Day 1** | Chicken Stir Fry         | N/A                        | $19.75|
# | **Day 2** | Chicken & Rice Fried Rice | Yes (leftover chicken, rice, veggies) | $0.00 |
# | **Day 3** | Chicken & Veggie Lettuce Wraps | Yes (leftover chicken, veggies) | $0.00 |
# | **Day 4** | Veggie & Chicken Soup    | Yes (leftover chicken, veggies, rice) | $0.00 |
# | **Day 5** | Spicy Garlic Chicken & Rice Bowl | Yes (leftover chicken, rice) | $0.00 |
# | **Day 6** | Quick Pickled Onions & Carrots | Yes (leftover onion, carrot) | $0.00 |
# | **Day 7** | Garlic & Ginger Chicken Stock | Yes (leftover chicken, veggies) | $0.00 |
#
# **Total Cost for 7 Days:** **$19.75** (well under $25 budget).
#
# ---
#
# ## **Final Notes:**
# - **All recipes are low-sodium and nut-free**, adhering to dietary restrictions.
# - **No additional ingredients are needed** for most recipes—just repurpose what you have!
# - **Budget remains under $25**, with room for optional ingredients like eggs or tofu.
# - **Minimize waste and maximize value** by creatively using leftovers.
#
# ---
# This comprehensive guide ensures you have **everything you need** to plan, shop, cook, and repurpose ingredients efficiently while staying within your budget!

# %% [markdown]
# ✅ Complete meal planning with summary completed!
# 📋 Complete Results:
# Comprehensive Meal Planning Guide for Easy Chicken Stir Fry**
#
# ---
#
# ## **1. Recipe and Cooking Instructions**
# **Meal Name:** Easy Chicken Stir Fry
# **Difficulty Level:** Beginner
# **Servings:** 4
# **Dietary Restrictions:** No nuts, low-sodium
# **Total Estimated Cost:** **$13.00** (well under $25 budget)
#
# ### **Ingredients:**
# #### **Marinade:**
# - 3 boneless, skinless chicken breasts (or 6-8 chicken thighs)
# - 2 tbsp olive oil
# - 2 tbsp low-sodium soy sauce (or coconut aminos)
# - 1 tbsp fresh lemon juice
# - 1 tbsp honey (or maple syrup)
# - 2 cloves garlic, minced
# - 1 tsp grated fresh ginger
# - ½ tsp black pepper
#
# #### **Stir-Fry:**
# - 2 tbsp olive oil (for stir-frying)
# - 1 bell pepper, sliced
# - 1 carrot, julienned
# - 1 small onion, sliced
# - 2 cups broccoli florets
# - 1 cup snap peas (optional)
# - 2 cloves garlic, minced
# - 1 tbsp fresh ginger, grated
# - 2 tbsp low-sodium soy sauce (or coconut aminos)
# - 1 tbsp rice vinegar
# - 1 tbsp honey (or maple syrup)
# - 1 tsp sesame oil (optional)
# - ½ tsp red pepper flakes (optional)
#
# ---
#
# ### **Instructions:**
# 1. **Marinate the chicken:** Combine chicken with olive oil, low-sodium soy sauce, lemon juice, honey, minced garlic, ginger, and black pepper. Refrigerate for at least 30 minutes.
# 2. **Prepare vegetables:** Slice bell pepper, julienne carrot, slice onion, and cut broccoli into florets. Trim snap peas if using.
# 3. **Cook the chicken:** Heat 1 tbsp olive oil in a skillet over medium-high heat. Cook chicken for 5-6 minutes per side until fully done. Remove and set aside.
# 4. **Stir-fry vegetables:** In the same skillet, add another tbsp of olive oil. Stir-fry onion, bell pepper, and carrot for 3-4 minutes. Add broccoli and snap peas, stir-fry for another 3-4 minutes.
# 5. **Combine and season:** Add minced garlic and ginger, stir-fry for 30 seconds. Pour in soy sauce, rice vinegar, honey, and sesame oil. Return chicken to skillet, toss to coat, and cook for 2 more minutes. Add red pepper flakes if using.
# 6. **Serve:** Serve hot over steamed rice or quinoa, garnished with fresh cilantro if desired.
#
# ---
#
# ## **2. Organized Shopping List with Prices**
#
# ### **Total Budget Allocation: $25**
#
# #### **Meat & Poultry ($4.50 - $7.00)**
# - **Boneless, skinless chicken breasts (or thighs):** 3 lbs (~$6.00) *or* 6-8 thighs (~$4.50)
#   - *Tip:* Chicken thighs are cheaper and more flavorful.
#
# #### **Produce ($5.00 - $8.00)**
# - **1 large bell pepper:** $1.50
# - **2 medium carrots:** $0.75
# - **1 yellow onion:** $0.50
# - **1 head fresh or frozen broccoli:** $2.00 (frozen is cheaper)
# - **1 cup snap peas (optional):** $1.50
# - **1 small knob fresh ginger:** $0.75
# - **1 head fresh garlic:** $0.50
# - **1 small lemon:** $0.50
#
# #### **Pantry Staples ($7.50 - $15.50, if buying new)**
# - **Olive oil:** $3.00 (if buying new)
# - **Low-sodium soy sauce or coconut aminos:** $2.50
# - **Honey or maple syrup:** $3.00
# - **Rice vinegar:** $2.00
# - **Sesame oil (optional):** $2.50
# - **Red pepper flakes (optional):** $1.50
# - **Black pepper (if needed):** $1.00
#
# #### **Grain ($2.00)**
# - **1 lb white rice or quinoa:** $2.00
#
# #### **Optional Garnish ($0.75)**
# - **Fresh cilantro:** $0.75
#
# #### **Frozen Foods (Alternative, $2.00)**
# - **Frozen stir-fry vegetable mix:** $2.00
#
# ---
#
# ### **Estimated Total Cost Breakdown:**
# | Category               | Estimated Cost | Notes                                  |
# |------------------------|----------------|----------------------------------------|
# | **Meat**               | $4.50 - $7.00  | Thighs are cheaper.                     |
# | **Produce**            | $5.00 - $8.00  | Frozen veggies save money.             |
# | **Pantry**             | $7.50 - $15.50 | Use existing staples if possible.      |
# | **Grain**              | $2.00          | Cook extra rice for future meals.       |
# | **Optional**           | $0.75 - $7.50  | Skip optional items to stay under budget.|
# | **Total**              | **$19.75 - $33.00** | **Budget-friendly range: $19.75 (minimal options) to $25 (with some extras).** |
#
# ---
#
# ## **3. Budget Analysis and Money-Saving Tips**
#
# ### **Budget Breakdown:**
# - **Total Budget:** $25
# - **Estimated Cost (Minimal Options):** **$19.75**
# - **Remaining Budget:** **$5.25** (for optional items like sesame oil, red pepper flakes, or cilantro).
#
# ### **Money-Saving Tips:**
# 1. **Use Chicken Thighs:** Save **$1.50** compared to chicken breasts.
# 2. **Buy Frozen Veggies:** Frozen broccoli or stir-fry mixes are cheaper and last longer.
# 3. **Skip Optional Items:** Avoid sesame oil, red pepper flakes, and snap peas to stay under budget.
# 4. **Use Maple Syrup Instead of Honey:** Save **$0.50**.
# 5. **Check Pantry First:** Avoid buying olive oil, soy sauce, or spices if you already have them.
# 6. **Cook Extra Rice:** Use leftover rice in other meals like fried rice or soups.
# 7. **Shop Sales:** Look for discounted meat, veggies, or grains.
# 8. **Marinate Chicken Overnight:** Save time on cooking day.
# 9. **Use Coconut Aminos:** Lower sodium alternative to soy sauce.
# 10. **Skip Cilantro:** Use parsley or another herb if cilantro is unavailable.
#
# ---
#
# ### **Alternative Ingredients (Budget Swaps):**
# | Original               | Budget Swap               | Cost Difference | Notes                                  |
# |------------------------|---------------------------|-----------------|----------------------------------------|
# | Chicken breasts        | Chicken thighs/drumsticks  | Save $1.50      | More flavorful.                        |
# | Fresh broccoli         | Frozen broccoli           | Save $0.50      | No waste, same nutrition.              |
# | Honey                  | Maple syrup               | Save $0.50      | Cheaper and similar sweetness.         |
# | Bell pepper            | Zucchini or cabbage       | Save $1.00      | Great for stir-fry.                    |
# | Low-sodium soy sauce   | Coconut aminos            | +$1.50         | Lower sodium, but pricier. Use sparingly.|
#
# ---
#
# ## **4. Leftover Management Suggestions**
#
# ### **Leftover Ingredients from Chicken Stir Fry:**
# 1. **Chicken:** Marinated or cooked portions.
# 2. **Vegetables:** Bell pepper, carrot, onion, broccoli, snap peas.
# 3. **Pantry Staples:** Soy sauce, rice vinegar, honey/maple syrup, garlic, ginger.
# 4. **Grain:** Extra cooked rice.
#
# ---
#
# ### **Creative Ways to Use Leftovers:**
#
# #### **1. Chicken & Rice Fried Rice**
# **Uses:** Leftover chicken, rice, veggies, soy sauce, vinegar, garlic, ginger.
# **Cost:** ~$0
# **Instructions:**
# 1. Heat olive oil, sauté garlic, ginger, and leftover veggies.
# 2. Add leftover rice and leftover chicken.
# 3. Stir in soy sauce, rice vinegar, and black pepper.
# 4. Optional: Add an egg for extra protein.
#
# ---
#
# #### **2. Chicken & Veggie Lettuce Wraps**
# **Uses:** Leftover chicken, veggies, soy sauce, vinegar, garlic, ginger.
# **Cost:** ~$0
# **Instructions:**
# 1. Stir-fry leftover veggies with garlic and ginger.
# 2. Add leftover chicken and season with soy sauce and vinegar.
# 3. Serve in butter lettuce or romaine leaves.
#
# ---
#
# #### **3. Veggie & Chicken Soup**
# **Uses:** Leftover chicken, veggies, soy sauce, vinegar, garlic, ginger, extra rice.
# **Cost:** ~$0
# **Instructions:**
# 1. Sauté garlic, ginger, and veggies in a pot.
# 2. Add water or broth, leftover chicken, and soy sauce.
# 3. Simmer for 20 minutes. Optional: Add leftover rice for thickness.
#
# ---
#
# #### **4. Spicy Garlic Chicken & Rice Bowl**
# **Uses:** Leftover chicken, rice, garlic, ginger, red pepper flakes (optional).
# **Cost:** ~$0
# **Instructions:**
# 1. Stir-fry leftover chicken with garlic, ginger, and red pepper flakes.
# 2. Serve over leftover rice.
#
# ---
#
# #### **5. Quick Pickled Onions & Carrots**
# **Uses:** Leftover onion, carrot, rice vinegar, sugar/maple syrup.
# **Cost:** ~$0
# **Instructions:**
# 1. Thinly slice onion and julienne carrot.
# 2. Mix with rice vinegar, sugar/maple syrup, and water.
# 3. Let sit for 30 minutes. Use as a topping for rice bowls or wraps.
#
# ---
#
# #### **6. Garlic & Ginger Chicken Stock**
# **Uses:** Leftover chicken, veggie scraps, garlic, ginger.
# **Cost:** ~$0
# **Instructions:**
# 1. Sauté garlic, ginger, and veggie scraps in a pot.
# 2. Add water and leftover chicken. Simmer for 20-30 minutes.
# 3. Strain and use as a base for soups or sauces.
#
# ---
#
# ### **Additional Tips for Leftover Management:**
# - **Store properly:** Keep chicken and veggies in airtight containers in the fridge for up to 3 days or freeze for longer storage.
# - **Use freezer-friendly containers:** Portion leftovers into freezer-safe containers for future meals.
# - **Repurpose veggie scraps:** Save carrot tops, onion skins, and bell pepper stems to make homemade veggie broth.
# - **Buy in bulk:** Garlic, ginger, and onions last longer than pre-minced or pre-grated versions.
# - **Meal prep:** Cook extra rice or grains to use in multiple meals.
#
# ---
#
# ## **5. Sample Meal Plan Using Leftovers (Within $25 Budget)**
#
# | Day       | Meal                     | Uses Leftover Ingredients? | Cost  |
# |-----------|--------------------------|----------------------------|-------|
# | **Day 1** | Chicken Stir Fry         | N/A                        | $19.75|
# | **Day 2** | Chicken & Rice Fried Rice | Yes (leftover chicken, rice, veggies) | $0.00 |
# | **Day 3** | Chicken & Veggie Lettuce Wraps | Yes (leftover chicken, veggies) | $0.00 |
# | **Day 4** | Veggie & Chicken Soup    | Yes (leftover chicken, veggies, rice) | $0.00 |
# | **Day 5** | Spicy Garlic Chicken & Rice Bowl | Yes (leftover chicken, rice) | $0.00 |
# | **Day 6** | Quick Pickled Onions & Carrots | Yes (leftover onion, carrot) | $0.00 |
# | **Day 7** | Garlic & Ginger Chicken Stock | Yes (leftover chicken, veggies) | $0.00 |
#
# **Total Cost for 7 Days:** **$19.75** (well under $25 budget).
#
# ---
#
# ## **Final Notes:**
# - **All recipes are low-sodium and nut-free**, adhering to dietary restrictions.
# - **No additional ingredients are needed** for most recipes—just repurpose what you have!
# - **Budget remains under $25**, with room for optional ingredients like eggs or tofu.
# - **Minimize waste and maximize value** by creatively using leftovers.
#
# ---
# This comprehensive guide ensures you have **everything you need** to plan, shop, cook, and repurpose ingredients efficiently while staying within your budget!

# %% [markdown]
# ### Understanding Your Complete Grocery Shopping Guide
#
# Congratulations! You've successfully created an AI-powered grocery shopping assistant that transforms a simple meal request into a comprehensive shopping strategy.
#
# **What You've Accomplished:**
# - **Automated Recipe Research**: No more browsing endless recipes online
# - **Organized Shopping Lists**: Items grouped by store sections for efficient shopping
# - **Budget Management**: Cost analysis and money-saving recommendations
# - **Dietary Compliance**: All suggestions respect your dietary restrictions and cooking skill level
# - **Waste Reduction**: Creative leftover management with bonus recipes to maximize your grocery budget
# - **Comprehensive Reporting**: All information compiled into one easy-to-follow guide
#
# **Next Steps:**
# You can now adapt this framework for any cuisine, dietary need, or budget constraint. Try different meal requests, adjust serving sizes, experiment with various dietary restrictions, or test different cooking skill levels to see how the system adapts. The five-agent team will handle everything from recipe research to waste reduction, ensuring you get maximum value from every grocery trip.

# %% [markdown]
# # Exercises
#
# It's now time to apply what you've learned! These exercises will help you extend the grocery planning system and understand how to adapt it for different scenarios.

# %% [markdown]
# ### Exercise 1 - Create a Specialized Dietary Agent
#
# **Objective:**
#
# Add a fourth agent that specializes in dietary analysis and nutritional recommendations.
#
# **Create a new agent called nutrition_analyst that:**
# * Analyzes the nutritional content of meal plans.
# * Suggests healthier alternatives when needed.
# * Provides calorie and macronutrient estimates.
# * Considers specific dietary goals (weight loss, muscle building, etc).
#
# **Requirements:**
# 1. Create the agent with appropriate role, goal, and backstory
# 2. Define a task that analyzes the meal plan for nutritional value
# 3. Add it to your crew workflow
# 4. Test it with a meal request that includes nutritional goals

# %%
# Your code here
nutrition_analyst = Agent(
    role="",  # TODO: Define the role
    goal="",  # TODO: Define the goal  
    backstory="",  # TODO: Create backstory
    tools=[],  # TODO: Add appropriate tools
    llm=llm,
    verbose=False
)

# TODO: Create nutrition analysis task
# TODO: Add to crew and test

# %%
nutrition_analyst = Agent(
    role="Nutrition Analyst & Health Advisor",
    goal="Analyze meal nutritional content and provide healthy recommendations",
    backstory="A certified nutritionist who evaluates meals for nutritional balance, calorie content, and health optimization while respecting dietary restrictions.",
    tools=[SerperDevTool()],
    llm=llm,
    verbose=False
)

nutrition_task = Task(
    description=(
        "Analyze the nutritional content of the '{meal_name}' meal plan for {servings} people. "
        "Calculate approximate calories, protein, carbs, and fats. Consider dietary restrictions: {dietary_restrictions}. "
        "Provide healthy alternatives if the meal could be more nutritious while staying within {budget}."
    ),
    expected_output="Nutritional analysis with calorie estimates, macronutrient breakdown, and healthy improvement suggestions.",
    agent=nutrition_analyst,
    context=[meal_planning_task, shopping_task, budget_task],
    output_file="nutrition_analysis.md"
)

# Test with expanded crew
health_focused_crew = Crew(
    agents=[meal_planner, shopping_organizer, budget_advisor, nutrition_analyst, yaml_leftover_manager, summary_agent],
    tasks=[meal_planning_task, shopping_task, budget_task, nutrition_task, yaml_leftover_task, summary_task],
    process=Process.sequential,
    verbose=True
)

result = health_focused_crew.kickoff(
    inputs={
        "meal_name": "Quinoa Buddha Bowl",
        "servings": 2,
        "budget": "$20",
        "dietary_restrictions": ["vegetarian", "high protein"],
        "cooking_skill": "intermediate"
    }
)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1a30587a-3e44-439c-92f1-490eba0fb393                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Task: Search for the best 'Quinoa Buddha Bowl' recipe for 2 people within a $20 budget. Consider dietary       │
# │  restrictions: ['vegetarian', 'high protein'] and cooking skill level: intermediate. Find recipes that match    │
# │  the skill level and provide complete ingredient lists with quantities.                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate   │
# │  skill level site:allrecipes.com', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [], 'credits':  │
# │  1}                                                                                                             │
# │                                                                                                                 │
# │                                                                                                                 │
# │  You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:          │
# │                                                                                                                 │
# │  Tool Name: Search the internet with Serper                                                                     │
# │  Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the         │
# │  internet', 'type': 'str'}}                                                                                     │
# │  Tool Description: A tool that can be used to search the internet with a search_query. Supports different       │
# │  search types: 'search' (default), 'news'                                                                       │
# │                                                                                                                 │
# │  IMPORTANT: Use the following format in your response:                                                          │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: you should always think about what to do                                                              │
# │  Action: the action to take, only one name of [Search the internet with Serper], just the name, exactly as      │
# │  it's written.                                                                                                  │
# │  Action Input: the input to the action, just a simple JSON object, enclosed in curly braces, using " to wrap    │
# │  keys and values.                                                                                               │
# │  Observation: the result of the action                                                                          │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  Once all necessary information is gathered, return the following format:                                       │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  Thought: I now know the final answer                                                                           │
# │  Final Answer: the final answer to the original input question                                                  │
# │  ```                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /Users/carlos/Library/Mobile Documents/com~apple~CloudDocs/Courses/2026/05_Building AI Agents and Agentic Workflows
# Specialization/99_Labs/.venv/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate   │
# │  skill level site:eatingwell.com', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title':      │
# │  'What to Eat with Diabetes: Free-Food Basics - EatingWell', 'link':                                            │
# │  'https://www.eatingwell.com/article/291165/what-to-eat-with-diabetes-free-food-basics/', 'snippet': 'For       │
# │  people with diabetes, free foods make good choices for snacking or as flavor enhancers. Find out what foods    │
# │  count as free and get ideas ...', 'position': 1}, {'title': 'Can You Lose Weight After Menopause? -            │
# │  EatingWell', 'link': 'https://www.eatingwell.com/article/291123/can-you-lose-weight-after-menopause/',         │
# │  'snippet': "Is It Really Harder to Lose Weight After Menopause? containers. Featured Recipe: Black             │
# │  Bean-Quinoa Bowl. It's possible to lose ...", 'position': 2, 'sitelinks': [{'title': 'Menopause And Weight     │
# │  Gain', 'link':                                                                                                 │
# │  'https://www.eatingwell.com/article/291123/can-you-lose-weight-after-menopause/#:~:text=Menopause%20and%20Wei  │
# │  ght%20Gain'}, {'title': 'Increasing Exercise May Be A...', 'link':                                             │
# │  'https://www.eatingwell.com/article/291123/can-you-lose-weight-after-menopause/#:~:text=Increasing%20Exercise  │
# │  %20May%20Be%20a%20Key%20to%20Success'}, {'title': 'Lifestyle Changes For Losing...', 'link':                   │
# │  'https://www.eatingwell.com/article/291123/can-you-lose-weight-after-menopause/#:~:text=Lifestyle%20Changes%2  │
# │  0for%20Losing%20Weight%20After%20Menopause'}]}], 'credits': 1}                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill
# level site:bbcgoodfood.com"}, {"search_query": "high protein vegetarian quinoa buddha bowl recipe budget under 20
# dollars site:minimalistbaker.com"}]
# Repaired JSON: [{"search_query": "vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill
# level site:bbcgoodfood.com"}, {"search_query": "high protein vegetarian quinoa buddha bowl recipe budget under 20
# dollars site:minimalistbaker.com"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill leve  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": {"description": "high protein vegetarian quinoa buddha bowl recipe for 2 people
# intermediate skill level budget under 20 dollars", "type": "str"}}, {"search_query": "high protein vegetarian
# quinoa buddha bowl recipe for 2 people intermediate skill level budget under $20 site:minimalistbaker.com"},
# {"search_query": "best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate skill level
# site:allrecipes.com"}, {"search_query": "high protein vegetarian quinoa buddha bowl recipe with ingredient costs
# for 2 people intermediate skill level"}]
# Repaired JSON: [{"search_query": {"description": "high protein vegetarian quinoa buddha bowl recipe for 2 people
# intermediate skill level budget under 20 dollars", "type": "str"}}, {"search_query": "high protein vegetarian
# quinoa buddha bowl recipe for 2 people intermediate skill level budget under $20 site:minimalistbaker.com"},
# {"search_query": "best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate skill level
# site:allrecipes.com"}, {"search_query": "high protein vegetarian quinoa buddha bowl recipe with ingredient costs
# for 2 people intermediate skill level"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": {\"description\": \"high protein vegetarian quinoa buddha bowl recipe for 2 people inter  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate
# skill level with ingredient costs and budget under $20"}, {"search_query": "detailed vegetarian quinoa buddha bowl
# recipe with ingredient quantities and budget breakdown site:eatingwell.com"}, {"search_query": "vegetarian quinoa
# buddha bowl recipe with high protein and budget-friendly ingredient list site:bbcgoodfood.com"}, {"search_query":
# "high protein quinoa buddha bowl recipe for 2 people with ingredient costs and budget under $20
# site:minimalistbaker.com"}]
# Repaired JSON: [{"search_query": "best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate
# skill level with ingredient costs and budget under $20"}, {"search_query": "detailed vegetarian quinoa buddha bowl
# recipe with ingredient quantities and budget breakdown site:eatingwell.com"}, {"search_query": "vegetarian quinoa
# buddha bowl recipe with high protein and budget-friendly ingredient list site:bbcgoodfood.com"}, {"search_query":
# "high protein quinoa buddha bowl recipe for 2 people with ingredient costs and budget under $20
# site:minimalistbaker.com"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate skill  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate
# skill level with full ingredient quantities and cost breakdown"}, {"search_query": "vegetarian quinoa buddha bowl
# recipe with chickpeas, tofu, or lentils for high protein, budget under $20, ingredient quantities"},
# {"search_query": "high protein vegetarian quinoa bowl recipe with lentils and chickpeas, 2 servings, intermediate,
# cost breakdown"}, {"search_query": "vegetarian quinoa buddha bowl recipe with chickpeas, lentils, and tofu,
# detailed ingredient list with quantities, budget under $20"}]
# Repaired JSON: [{"search_query": "best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate
# skill level with full ingredient quantities and cost breakdown"}, {"search_query": "vegetarian quinoa buddha bowl
# recipe with chickpeas, tofu, or lentils for high protein, budget under $20, ingredient quantities"},
# {"search_query": "high protein vegetarian quinoa bowl recipe with lentils and chickpeas, 2 servings, intermediate,
# cost breakdown"}, {"search_query": "vegetarian quinoa buddha bowl recipe with chickpeas, lentils, and tofu,
# detailed ingredient list with quantities, budget under $20"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate
# skill level site:allrecipes.com"}, {"search_query": "high protein vegetarian quinoa buddha bowl recipe with
# ingredient costs for 2 people budget under $20"}, {"search_query": "budget-friendly high protein vegetarian quinoa
# bowl recipe with chickpeas, lentils, and tofu, ingredient quantities"}, {"search_query": "vegetarian quinoa buddha
# bowl recipe with chickpeas and lentils, detailed ingredients, 2 servings, intermediate"}, {"search_query": "high
# protein quinoa bowl recipe with tofu and chickpeas, cost breakdown, 2 servings"}, {"search_query": "detailed recipe
# for quinoa buddha bowl with chickpeas, lentils, and avocado, ingredient quantities, budget under $20"}]
# Repaired JSON: [{"search_query": "best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate
# skill level site:allrecipes.com"}, {"search_query": "high protein vegetarian quinoa buddha bowl recipe with
# ingredient costs for 2 people budget under $20"}, {"search_query": "budget-friendly high protein vegetarian quinoa
# bowl recipe with chickpeas, lentils, and tofu, ingredient quantities"}, {"search_query": "vegetarian quinoa buddha
# bowl recipe with chickpeas and lentils, detailed ingredients, 2 servings, intermediate"}, {"search_query": "high
# protein quinoa bowl recipe with tofu and chickpeas, cost breakdown, 2 servings"}, {"search_query": "detailed recipe
# for quinoa buddha bowl with chickpeas, lentils, and avocado, ingredient quantities, budget under $20"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"best vegetarian high protein quinoa buddha bowl recipe for 2 people intermediate skill  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "best vegetarian high protein quinoa buddha bowl recipe for 2 people with
# ingredient quantities and cost breakdown under $20"}, {"search_query": "high protein vegetarian quinoa buddha bowl
# recipe with chickpeas, lentils, and tofu, full ingredient list with quantities, intermediate skill level"},
# {"search_query": "vegetarian quinoa bowl recipe with high protein, budget-friendly, 2 servings, ingredient costs"},
# {"search_query": "vegetarian quinoa buddha bowl recipe with chickpeas, lentils, and tofu, detailed ingredients, 2
# servings, budget under $20"}, {"search_query": "high protein quinoa buddha bowl recipe for 2 people, intermediate,
# ingredient costs, site:minimalistbaker.com"}]
# Repaired JSON: [{"search_query": "best vegetarian high protein quinoa buddha bowl recipe for 2 people with
# ingredient quantities and cost breakdown under $20"}, {"search_query": "high protein vegetarian quinoa buddha bowl
# recipe with chickpeas, lentils, and tofu, full ingredient list with quantities, intermediate skill level"},
# {"search_query": "vegetarian quinoa bowl recipe with high protein, budget-friendly, 2 servings, ingredient costs"},
# {"search_query": "vegetarian quinoa buddha bowl recipe with chickpeas, lentils, and tofu, detailed ingredients, 2
# servings, budget under $20"}, {"search_query": "high protein quinoa buddha bowl recipe for 2 people, intermediate,
# ingredient costs, site:minimalistbaker.com"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"best vegetarian high protein quinoa buddha bowl recipe for 2 people with ingredient qu  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "high protein vegetarian quinoa buddha bowl recipe for 2 people, intermediate,
# ingredient list with quantities and cost breakdown"}, {"search_query": "high protein vegetarian quinoa bowl recipe
# with chickpeas, lentils, and avocado, ingredient quantities, budget under $20, detailed instructions"},
# {"search_query": "budget-friendly high protein quinoa bowl recipe with chickpeas and quinoa, 2 servings,
# intermediate, ingredient costs"}]
# Repaired JSON: [{"search_query": "high protein vegetarian quinoa buddha bowl recipe for 2 people, intermediate,
# ingredient list with quantities and cost breakdown"}, {"search_query": "high protein vegetarian quinoa bowl recipe
# with chickpeas, lentils, and avocado, ingredient quantities, budget under $20, detailed instructions"},
# {"search_query": "budget-friendly high protein quinoa bowl recipe with chickpeas and quinoa, 2 servings,
# intermediate, ingredient costs"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"high protein vegetarian quinoa buddha bowl recipe for 2 people, intermediate, ingredie  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Repaired JSON: [{"search_query": "best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate
# skill level site:minimalistbaker.com"}, {"search_query": "vegetarian quinoa buddha bowl recipe with chickpeas,
# lentils, and tahini, ingredient quantities, budget under $20"}, {"search_query": "high protein quinoa bowl recipe
# with tofu, chickpeas, and quinoa, detailed ingredient list, cost breakdown"}, {"search_query": "high protein
# vegetarian quinoa buddha bowl recipe for 2 people, intermediate, ingredient list with quantities, cost breakdown
# under $20"}]
# Repaired JSON: [{"search_query": "best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate
# skill level site:minimalistbaker.com"}, {"search_query": "vegetarian quinoa buddha bowl recipe with chickpeas,
# lentils, and tahini, ingredient quantities, budget under $20"}, {"search_query": "high protein quinoa bowl recipe
# with tofu, chickpeas, and quinoa, detailed ingredient list, cost breakdown"}, {"search_query": "high protein
# vegetarian quinoa buddha bowl recipe for 2 people, intermediate, ingredient list with quantities, cost breakdown
# under $20"}]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "[{\"search_query\": \"best high protein vegetarian quinoa buddha bowl recipe for 2 people intermediate skill  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Error: the Action Input is not a valid key, value dictionary.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  {                                                                                                              │
# │    "meal_name": "High-Protein Vegetarian Quinoa Buddha Bowl with Chickpeas, Lentils, and Avocado",              │
# │                                                                                                                 │
# │    "difficulty_level": "intermediate",                                                                          │
# │                                                                                                                 │
# │    "servings": 2,                                                                                               │
# │                                                                                                                 │
# │    "researched_ingredients": [                                                                                  │
# │      "1 cup quinoa, uncooked (about 180g)",                                                                     │
# │      "1 cup water or vegetable broth",                                                                          │
# │      "1 cup dried lentils (about 200g)",                                                                        │
# │      "1 can (15 oz) chickpeas, drained and rinsed (about 240g)",                                                │
# │      "1 medium avocado, sliced (about 150g)",                                                                   │
# │      "1 cup baby spinach (about 30g)",                                                                          │
# │      "1 small red bell pepper, sliced (about 100g)",                                                            │
# │      "1/2 cup crumbled feta cheese (optional, about 50g)",                                                      │
# │      "1 tbsp olive oil",                                                                                        │
# │      "1 tbsp lemon juice",                                                                                      │
# │      "1 tsp ground cumin",                                                                                      │
# │      "1 tsp smoked paprika",                                                                                    │
# │      "1/2 tsp garlic powder",                                                                                   │
# │      "1/2 tsp salt",                                                                                            │
# │      "1/4 tsp black pepper",                                                                                    │
# │      "1 tbsp tahini (optional)",                                                                                │
# │      "1 tbsp chopped fresh parsley",                                                                            │
# │      "1 tbsp chopped red onion (optional)"                                                                      │
# │    ],                                                                                                           │
# │                                                                                                                 │
# │    "instructions": [                                                                                            │
# │      "1. Rinse 1 cup of quinoa under cold water. Combine with 1 cup of water or vegetable broth in a pot,       │
# │  bring to a boil, reduce heat, cover, and simmer for 15 minutes. Let it sit covered for another 5 minutes,      │
# │  then fluff with a fork.",                                                                                      │
# │      "2. Rinse 1 cup of dried lentils. Cook in 2 cups of water for 20-25 minutes until tender. Drain excess     │
# │  water.",                                                                                                       │
# │      "3. Mix 1 can of drained chickpeas with 1 tbsp olive oil, 1 tbsp lemon juice, 1 tsp cumin, 1 tsp smoked    │
# │  paprika, 1/2 tsp garlic powder, 1/2 tsp salt, and 1/4 tsp black pepper.",                                      │
# │      "4. Divide cooked quinoa evenly between two bowls. Top each with 1/2 cup cooked lentils and 1/2 cup        │
# │  seasoned chickpeas.",                                                                                          │
# │      "5. Add baby spinach and sliced red bell pepper to each bowl.",                                            │
# │      "6. Top each serving with 1/2 avocado, sliced. Optionally, add crumbled feta cheese, drizzle with tahini,  │
# │  and garnish with parsley and red onion.",                                                                      │
# │      "7. Serve and enjoy!"                                                                                      │
# ...
# │     - Uses leftover quinoa, lentils, and bell pepper.                                                           │
# │  2. **Chickpea & Avocado Toast** (~$1)                                                                          │
# │     - Uses leftover chickpeas and avocado.                                                                      │
# │  3. **Lentil & Spinach Soup** ($0)                                                                              │
# │     - Uses leftover lentils, spinach, and broth.                                                                │
# │                                                                                                                 │
# │  **Total Leftover Meals Cost:** **$1.00**                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **📊 Final Budget Summary**                                                                                │
# │  | **Category**               | **Cost**       |                                                                │
# │  |----------------------------|----------------|                                                                │
# │  | Original Meal              | $17.50         |                                                                │
# │  | Leftover Meals             | $1.00          |                                                                │
# │  | **Remaining Budget**       | **$1.50**      |                                                                │
# │                                                                                                                 │
# │  **Use remaining $1.50 for:**                                                                                   │
# │  - Extra herbs, nuts, or a small snack.                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  **Outcome:**                                                                                                   │
# │  This guide ensures **zero waste, maximum protein, and full budget utilization** while providing **four         │
# │  delicious meals** from a single recipe. Follow the steps to **save money, reduce waste, and enjoy a            │
# │  high-protein vegetarian diet**!                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 863d9135-cd8a-465e-b63d-e3385c3c6427                                                                     │
# │  Agent: Report Compiler                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 1a30587a-3e44-439c-92f1-490eba0fb393                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **                                                                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  # **High-Protein Vegetarian Quinoa Buddha Bowl Meal Plan**                                                     │
# │  **Budget:** $20.00                                                                                             │
# │  **Servings:** 4 meals (2 main + 2 leftovers)                                                                   │
# │  **Difficulty:** Intermediate                                                                                   │
# │  **Time:** 20 min prep + 30 min cooking                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **📝 Recipe & Instructions**                                                                               │
# │  **High-Protein Quinoa Buddha Bowl**                                                                            │
# │  1. Cook quinoa and lentils as instructed.                                                                      │
# │  2. Season chickpeas with olive oil, lemon juice, and spices.                                                   │
# │  3. Assemble bowls with quinoa, lentils, chickpeas, spinach, and bell pepper.                                   │
# │  4. Top with avocado and optional feta/tahini.                                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **🛒 Shopping List (Aldi Prices)**                                                                         │
# │  **Dry Goods:**                                                                                                 │
# │  - Quinoa (1 small bag): **$3.50**                                                                              │
# │  - Dried Lentils (16 oz): **$2.00**                                                                             │
# │                                                                                                                 │
# │  **Canned Goods:**                                                                                              │
# │  - Chickpeas (1 can): **$1.20** *(or black beans for $0.79)*                                                    │
# │                                                                                                                 │
# │  **Produce:**                                                                                                   │
# │  - Avocado (1): **$0.99**                                                                                       │
# │  - Baby Spinach (5 oz): **$1.50**                                                                               │
# │  - Red Bell Pepper (1): **$0.75**                                                                               │
# │  - Fresh Parsley (1 bunch): **$0.75**                                                                           │
# │                                                                                                                 │
# │  **Condiments/Oils:**                                                                                           │
# │  - Olive Oil (4 oz): **$4.00**                                                                                  │
# │  - Lemon Juice (4 oz): **$1.50**                                                                                │
# │                                                                                                                 │
# │  **Spices:**                                                                                                    │
# │  - Ground Cumin: **$2.50**                                                                                      │
# │  - Smoked Paprika: **$2.00**                                                                                    │
# │  - Garlic Powder: **$1.50**                                                                                     │
# │                                                                                                                 │
# │  **Optional:**                                                                                                  │
# │  - Feta Cheese (4 oz): **$2.00** *(skip to save $2.00)*                                                         │
# │  - Tahini (4 oz): **$3.00** *(skip to save $3.00)*                                                              │
# │                                                                                                                 │
# │  **Total (without optional items):** **$17.50**                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **💰 Budget Breakdown & Tips**                                                                             │
# │  - **Base Cost:** $17.50                                                                                        │
# │  - **Savings:** Skip feta/tahini ($5.00), use black beans ($0.41 savings).                                      │
# │  - **Money-Saving Tips:**                                                                                       │
# │    - Buy dried beans/lentils instead of canned.                                                                 │
# │    - Use frozen spinach ($1.00 for 16 oz).                                                                      │
# │    - Cook extra quinoa/lentils for future meals.                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **🍽️ Leftover Meals (Zero-Waste Plan)**                                                                     │
# │  1. **Quinoa & Lentil Stuffed Peppers** ($0)                                                                    │
# │     - Uses leftover quinoa, lentils, and bell pepper.                                                           │
# │  2. **Chickpea & Avocado Toast** (~$1)                                                                          │
# │     - Uses leftover chickpeas and avocado.                                                                      │
# │  3. **Lentil & Spinach Soup** ($0)                                                                              │
# │     - Uses leftover lentils, spinach, and broth.                                                                │
# │                                                                                                                 │
# │  **Total Leftover Meals Cost:** **$1.00**                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **📊 Final Budget Summary**                                                                                │
# │  | **Category**               | **Cost**       |                                                                │
# │  |----------------------------|----------------|                                                                │
# │  | Original Meal              | $17.50         |                                                                │
# │  | Leftover Meals             | $1.00          |                                                                │
# │  | **Remaining Budget**       | **$1.50**      |                                                                │
# │                                                                                                                 │
# │  **Use remaining $1.50 for:**                                                                                   │
# │  - Extra herbs, nuts, or a small snack.                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  **Outcome:**                                                                                                   │
# │  This guide ensures **zero waste, maximum protein, and full budget utilization** while providing **four         │
# │  delicious meals** from a single recipe. Follow the steps to **save money, reduce waste, and enjoy a            │
# │  high-protein vegetarian diet**!                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# <details>
#     <summary>Click here for the solution</summary>
#
# ```python
# nutrition_analyst = Agent(
#     role="Nutrition Analyst & Health Advisor",
#     goal="Analyze meal nutritional content and provide healthy recommendations",
#     backstory="A certified nutritionist who evaluates meals for nutritional balance, calorie content, and health optimization while respecting dietary restrictions.",
#     tools=[SerperDevTool()],
#     llm=llm,
#     verbose=False
# )
#
# nutrition_task = Task(
#     description=(
#         "Analyze the nutritional content of the '{meal_name}' meal plan for {servings} people. "
#         "Calculate approximate calories, protein, carbs, and fats. Consider dietary restrictions: {dietary_restrictions}. "
#         "Provide healthy alternatives if the meal could be more nutritious while staying within {budget}."
#     ),
#     expected_output="Nutritional analysis with calorie estimates, macronutrient breakdown, and healthy improvement suggestions.",
#     agent=nutrition_analyst,
#     context=[meal_planning_task, shopping_task, budget_task],
#     output_file="nutrition_analysis.md"
# )
#
# # Test with expanded crew
# health_focused_crew = Crew(
#     agents=[meal_planner, shopping_organizer, budget_advisor, nutrition_analyst, yaml_leftover_manager, summary_agent],
#     tasks=[meal_planning_task, shopping_task, budget_task, nutrition_task, yaml_leftover_task, summary_task],
#     process=Process.sequential,
#     verbose=True
# )
#
# result = health_focused_crew.kickoff(
#     inputs={
#         "meal_name": "Quinoa Buddha Bowl",
#         "servings": 2,
#         "budget": "$20",
#         "dietary_restrictions": ["vegetarian", "high protein"],
#         "cooking_skill": "intermediate"
#     }
# )
# ```
# </details>

# %% [markdown]
# ### Exercise 2 - Extend Pydantic Models for Weekly Planning
#
# **Objective:**
#
# Modify the existing Pydantic models to handle weekly meal planning instead of single meals.
#
# **Create new Pydantic models that can handle:**
#
# * Multiple meals across a week.
# * Different meal types (breakfast, lunch, dinner).
# * Weekly budget distribution.
# * Bulk shopping optimization.
#
# **Requirements:**
#
# 1. Create a WeeklyMealPlan model
# 2. Create a MealType enum (breakfast, lunch, dinner)
# 3. Modify GroceryShoppingPlan to handle weekly shopping
# 4. Test with a week's worth of meals

# %%
from enum import Enum
from typing import Dict

# TODO: Create MealType enum
class MealType(str, Enum):
    # Add meal types here
    pass

# TODO: Create WeeklyMealPlan model
class WeeklyMealPlan(BaseModel):
    # Add fields for weekly planning
    pass

# TODO: Create WeeklyGroceryPlan model
class WeeklyGroceryPlan(BaseModel):
    # Extend GroceryShoppingPlan for weekly use
    pass

# TODO: Test your models

# %%
from enum import Enum
from typing import Dict

class MealType(str, Enum):
    BREAKFAST = "breakfast"
    LUNCH = "lunch" 
    DINNER = "dinner"
    SNACK = "snack"

class DailyMeals(BaseModel):
    """Meals for one day"""
    date: str = Field(description="Date in YYYY-MM-DD format")
    breakfast: Optional[MealPlan] = Field(default=None, description="Breakfast meal plan")
    lunch: Optional[MealPlan] = Field(default=None, description="Lunch meal plan") 
    dinner: Optional[MealPlan] = Field(default=None, description="Dinner meal plan")
    snacks: Optional[List[MealPlan]] = Field(default=None, description="Snack meal plans")
class WeeklyMealPlan(BaseModel):
    """Complete weekly meal planning"""
    week_start_date: str = Field(description="Start date of the week")
    daily_meals: List[DailyMeals] = Field(description="Meals for each day")
    weekly_themes: List[str] = Field(description="Cooking themes for the week")
    prep_suggestions: List[str] = Field(description="Meal prep recommendations")

class WeeklyGroceryPlan(BaseModel):
    """Weekly grocery shopping strategy"""
    weekly_budget: str = Field(description="Total weekly budget")
    meal_plans: List[DailyMeals] = Field(description="All weekly meals")
    shopping_sections: List[ShoppingCategory] = Field(description="Organized by store sections")
    bulk_items: List[GroceryItem] = Field(description="Items to buy in bulk")
    shopping_tips: List[str] = Field(description="Weekly shopping efficiency tips")
    budget_breakdown: Dict[str, str] = Field(description="Daily budget allocation")

# Test the models
sample_weekly_plan = WeeklyMealPlan(
    week_start_date="2024-01-15",
    daily_meals=[
        DailyMeals(
            date="2024-01-15",
            breakfast=MealPlan(meal_name="Oatmeal", difficulty_level="Easy", servings=2, researched_ingredients=["oats", "milk", "berries"]),
            lunch=MealPlan(meal_name="Salad", difficulty_level="Easy", servings=2, researched_ingredients=["lettuce", "tomatoes", "dressing"]),
            dinner=MealPlan(meal_name="Pasta", difficulty_level="Medium", servings=2, researched_ingredients=["pasta", "sauce", "cheese"])
        )
    ],
    weekly_themes=["Italian Monday", "Taco Tuesday"],
    prep_suggestions=["Wash vegetables on Sunday", "Cook grains in bulk"]
)

display(JSON(sample_weekly_plan.model_dump()))

# %% [markdown]
# <details>
#     <summary>Click here for the solution</summary>
#
# ```python
# from enum import Enum
# from typing import Dict
#
# class MealType(str, Enum):
#     BREAKFAST = "breakfast"
#     LUNCH = "lunch"
#     DINNER = "dinner"
#     SNACK = "snack"
#
# class DailyMeals(BaseModel):
#     """Meals for one day"""
#     date: str = Field(description="Date in YYYY-MM-DD format")
#     breakfast: Optional[MealPlan] = Field(default=None, description="Breakfast meal plan")
#     lunch: Optional[MealPlan] = Field(default=None, description="Lunch meal plan")
#     dinner: Optional[MealPlan] = Field(default=None, description="Dinner meal plan")
#     snacks: Optional[List[MealPlan]] = Field(default=None, description="Snack meal plans")
# class WeeklyMealPlan(BaseModel):
#     """Complete weekly meal planning"""
#     week_start_date: str = Field(description="Start date of the week")
#     daily_meals: List[DailyMeals] = Field(description="Meals for each day")
#     weekly_themes: List[str] = Field(description="Cooking themes for the week")
#     prep_suggestions: List[str] = Field(description="Meal prep recommendations")
#
# class WeeklyGroceryPlan(BaseModel):
#     """Weekly grocery shopping strategy"""
#     weekly_budget: str = Field(description="Total weekly budget")
#     meal_plans: List[DailyMeals] = Field(description="All weekly meals")
#     shopping_sections: List[ShoppingCategory] = Field(description="Organized by store sections")
#     bulk_items: List[GroceryItem] = Field(description="Items to buy in bulk")
#     shopping_tips: List[str] = Field(description="Weekly shopping efficiency tips")
#     budget_breakdown: Dict[str, str] = Field(description="Daily budget allocation")
#
# # Test the models
# sample_weekly_plan = WeeklyMealPlan(
#     week_start_date="2024-01-15",
#     daily_meals=[
#         DailyMeals(
#             date="2024-01-15",
#             breakfast=MealPlan(meal_name="Oatmeal", difficulty_level="Easy", servings=2, researched_ingredients=["oats", "milk", "berries"]),
#             lunch=MealPlan(meal_name="Salad", difficulty_level="Easy", servings=2, researched_ingredients=["lettuce", "tomatoes", "dressing"]),
#             dinner=MealPlan(meal_name="Pasta", difficulty_level="Medium", servings=2, researched_ingredients=["pasta", "sauce", "cheese"])
#         )
#     ],
#     weekly_themes=["Italian Monday", "Taco Tuesday"],
#     prep_suggestions=["Wash vegetables on Sunday", "Cook grains in bulk"]
# )
#
# display(JSON(sample_weekly_plan.model_dump()))
# ```
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Karan Goswami](https://author.skills.network/instructors/karan_goswami)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Tenzin Migmar](https://author.skills.network/instructors/tenzin_migmar)
#
# [Jigisha Barbhaya](https://author.skills.network/instructors/jigisha_barbhaya)
#
# [Joseph Santarcangelo](https://author.skills.network/instructors/joseph_santarcangelo)

# %% [markdown]
# ## Change Log
#
# <details>
#     <summary>Click here for the changelog</summary>
#
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2025-07-25|0.1|Karan Goswami|Initial version created|
# |2025-07-26|0.2|Steve Ryan|ID review and format fixes|
# |2025-07-28|0.3|Leah Hanson|QA review and grammar fixes|
# |2025-10-13|0.4|Sathya Priya|Updated the code|
#
# </details>
#
# ---
#
#
# Copyright © IBM Corporation. All rights reserved.
